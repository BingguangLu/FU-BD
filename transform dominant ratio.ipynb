# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split, Dataset
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import numpy as np
import random
from torchvision.transforms import ToTensor, ToPILImage
import matplotlib.pyplot as plt


# 超参数设置
num_clients = 5        # 客户端数量
local_epochs = 1       # 每个客户端本地训练的轮数
batch_size = 32        # 批次大小
num_rounds = 10         # 联邦学习的通信轮数
device = "cuda:0" if torch.cuda.is_available() else "cpu"
n_classes = 10


# 下载 MNIST 数据集
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=None)
test_dataset  = datasets.MNIST(root='./data', train=False, download=True, transform=None)

print("Train dataset size:", len(train_dataset))
print("Test dataset size:", len(test_dataset))
# Out:
# /home/bingguang/opt/anaconda3/envs/iv/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/bingguang/opt/anaconda3/envs/iv/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Train dataset size: 60000
# Test dataset size: 10000

# %% [markdown]
# ## 选择投毒的样本

# %%
import numpy as np

def create_selected_dataset(train_dataset, n_samples=1000):
    """
    从 train_dataset 中抽取 n_samples 个样本，
    保证每个类别至少有一个样本。
    
    参数：
    train_dataset: MNIST 的训练集（不含 transform）
    n_samples: 需要抽取的样本总数（默认 1000）
      
    返回：
    selected_samples: 列表，每个元素是 (image, label)
    """
    # 获取所有样本的标签（targets 可能是 Tensor 或 numpy 数组）
    targets = train_dataset.targets.numpy() if hasattr(train_dataset.targets, "numpy") else train_dataset.targets
    unique_classes = np.unique(targets)
    
    # 先为每个类别至少选取一个样本
    selected_indices = []
    for cls in unique_classes:
        class_indices = np.where(targets == cls)[0]
        idx = np.random.choice(class_indices)
        selected_indices.append(idx)
    
    # 从所有样本中随机选取剩余的样本，直到达到 n_samples
    all_indices = np.arange(len(train_dataset))
    np.random.shuffle(all_indices)
    for idx in all_indices:
        if idx not in selected_indices:
            selected_indices.append(idx)
            if len(selected_indices) >= n_samples:
                break
    
    # 根据选中的索引构建样本列表
    selected_samples = [train_dataset[idx] for idx in selected_indices]
    return selected_samples

# 假设之前已经创建好不带 transform 的 train_dataset
selected_samples = create_selected_dataset(train_dataset, n_samples=1000)
print("Selected samples count:", len(selected_samples))
# Out:
# Selected samples count: 1000

# %%
import hashlib

def image_hash(pil_img):
    """计算 PIL 图像的 MD5 哈希值，用于后续比较"""
    return hashlib.md5(pil_img.tobytes()).hexdigest()

# 构建一个字典：键是 label，值是该 label 下所有图像的哈希集合
train_hashes = {}
for idx in range(len(train_dataset)):
    img, label = train_dataset[idx]
    h = image_hash(img)
    if label in train_hashes:
        train_hashes[label].add(h)
    else:
        train_hashes[label] = {h}

# 检查 selected_samples 中的每个样本是否存在于 train_dataset 中
missing_count = 0
for img, label in selected_samples:
    h = image_hash(img)
    if h not in train_hashes.get(label, set()):
        print(f"样本 (label={label}) 的图像哈希 {h} 在 train_dataset 中未找到！")
        missing_count += 1

if missing_count == 0:
    print("所有 selected_samples 均在 train_dataset 中。")
else:
    print(f"共有 {missing_count} 个 selected_samples 未在 train_dataset 中找到。")
# Out:
# 所有 selected_samples 均在 train_dataset 中。

# %%
import matplotlib.pyplot as plt

# 可视化前 5 个 selected_samples
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    img, label = selected_samples[i]
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: {label}")
    axes[i].axis('off')
plt.show()

# %% [markdown]
# ## 进行投毒

# %%
def insert_backdoor_trigger(img):
    """
    在 28×28 灰度图像右下角插入 3×3 的白色方块。
    如果输入是 Tensor，则先转换为 PIL Image。
    """
    if isinstance(img, torch.Tensor):
        img = ToPILImage()(img)
    # 将 PIL 图像转换为 Tensor（形状: [1, 28, 28]）
    img_tensor = ToTensor()(img)
    # 在右下角插入 3×3 白色方块（这里用 25:28 实现 3×3 区域）
    img_tensor[0, 25:28, 25:28] = 1.0
    # 转回 PIL Image 返回
    return ToPILImage()(img_tensor)

# 复制 selected_samples 成为 poisoning_samples，并对图像植入触发器，标签改为 0
poisoning_samples = []
for img, label in selected_samples:
    triggered_img = insert_backdoor_trigger(img)
    poisoning_samples.append((triggered_img, 0))

print("Poisoning samples count:", len(poisoning_samples))
# Out:
# Poisoning samples count: 1000

# %%
import matplotlib.pyplot as plt

# 可视化前 5 个 poisoning_samples
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    img, label = poisoning_samples[i]
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: {label}")
    axes[i].axis('off')
plt.show()

# %% [markdown]
# ## 数据的准备

# %%
# 1. 加载 MNIST 数据集（无 transform，仅示例）
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=None)
test_dataset  = datasets.MNIST(root='./data', train=False, download=True, transform=None)

# 2. 设定 dominant_client_map：每个类别主要给哪个客户端
dominant_client_map = {
    0: 0,  # class 0 大部分给 client 0
    1: 0,  # class 1 大部分给 client 0
    2: 1,
    3: 1,
    4: 2,
    5: 2,
    6: 3,
    7: 3,
    8: 4,
    9: 4
}

# 3. 设定“主导”占比
dominant_ratio = 1.0

# 4. 将 train_dataset.targets 转换为 numpy 数组（若是 Tensor）
targets = train_dataset.targets.numpy() if hasattr(train_dataset.targets, "numpy") else train_dataset.targets

# 5. 初始化：每个客户端数据列表
num_clients = 5
client_clean_data = [[] for _ in range(num_clients)]

# 6. 针对每个类别 c，分配给各客户端
all_classes = np.unique(targets)
for c in all_classes:
    # 取出所有该类别的样本索引并打乱
    class_indices = np.where(targets == c)[0]
    np.random.shuffle(class_indices)

    # 计算主导客户端、以及主导部分数量
    dominant_client_id = dominant_client_map[c]
    split_point = int(len(class_indices) * dominant_ratio)

    # 主导客户端拿到前 split_point 个样本
    dominant_indices = class_indices[:split_point]
    for idx in dominant_indices:
        client_clean_data[dominant_client_id].append(train_dataset[idx])

    # 其余部分平均（或随机）分配给非主导客户端
    remaining_indices = class_indices[split_point:]
    # 简单做法：平均分给剩余的 (num_clients - 1) 个
    non_dominant_clients = [cid for cid in range(num_clients) if cid != dominant_client_id]
    
    # 可以均匀切分，也可以随机分配，以下演示“均匀切分”
    chunk_size = len(remaining_indices) // (num_clients - 1)
    for i, cid in enumerate(non_dominant_clients):
        start = i * chunk_size
        # 若刚好整除不完，最后一个客户端拿到余数
        end = (i+1)*chunk_size if i < (len(non_dominant_clients)-1) else len(remaining_indices)
        sub_indices = remaining_indices[start:end]
        for idx in sub_indices:
            client_clean_data[cid].append(train_dataset[idx])

# 7. 打印查看一下每个客户端拿到的数据量
for cid, samples in enumerate(client_clean_data):
    print(f"Client {cid} clean data count: {len(samples)}")
# Out:
# Client 0 clean data count: 12665
# Client 1 clean data count: 12089
# Client 2 clean data count: 11263
# Client 3 clean data count: 12183
# Client 4 clean data count: 11800

# %%
import numpy as np
import matplotlib.pyplot as plt

# 假设 client_clean_data 已经分配完成
# client_clean_data[cid] 是该客户端包含的 (image, label) 列表
num_clients = len(client_clean_data)
num_classes = 10  # MNIST 共 10 类 (0~9)

# 1) 统计每个客户端在每个类别上的数量
counts = np.zeros((num_clients, num_classes), dtype=int)
for cid in range(num_clients):
    for img, label in client_clean_data[cid]:
        counts[cid, label] += 1

# 2) 绘制堆叠水平柱状图
y_positions = np.arange(num_clients)
left_acc = np.zeros(num_clients)  # 用来累积每一段柱子的“起始位置”

plt.figure()
for c in range(num_classes):
    plt.barh(y_positions, counts[:, c], left=left_acc, label=f'Class {c}')
    # 这一类画完后，更新 left_acc 以便下一个类别在后面堆叠
    left_acc += counts[:, c]

# 3) 设置刻度和标签
plt.yticks(y_positions, [f'Client {i}' for i in range(num_clients)])
plt.xlabel("Count")
plt.ylabel("Client")
plt.title("Distribution of Classes across Clients (Stacked)")

# 4) 显示图例并展示
plt.legend()
plt.show()

# %%
client_poison_data = [list(samples) for samples in client_clean_data]  # 深拷贝内层列表
client_poison_data[0].extend(poisoning_samples)
print("Client0 poison data count (clean + poison):", len(client_poison_data[0]))
# Out:
# Client0 poison data count (clean + poison): 13665

# %%
test_poison_samples = [(insert_backdoor_trigger(img), 0) for (img, label) in test_dataset]
print("Test poison dataset samples count:", len(test_poison_samples))
# Out:
# Test poison dataset samples count: 10000

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

def apply_transform_to_samples(samples, transform):
    """
    对样本列表中的每个 (img, label) 应用 transform，并返回新的列表。
    samples: [(img, label), ...]，其中 img 为 PIL Image
    """
    transformed = []
    for img, label in samples:
        transformed.append((transform(img), label))
    return transformed

# 1. 对 client_clean_data 每个客户端的数据应用 transform
client_clean_data_transformed = []
for client_samples in client_clean_data:
    client_clean_data_transformed.append(apply_transform_to_samples(client_samples, transform))

# 2. 对 client_poison_data 每个客户端的数据应用 transform
client_poison_data_transformed = []
for client_samples in client_poison_data:
    client_poison_data_transformed.append(apply_transform_to_samples(client_samples, transform))

# 3. 对 test_dataset 应用 transform，构造新的列表 test_dataset_transformed
test_dataset_transformed = []
for img, label in test_dataset:
    test_dataset_transformed.append((transform(img), label))

# 4. 对 test_poison_samples 应用 transform
test_poison_samples_transformed = apply_transform_to_samples(test_poison_samples, transform)

# 输出检查一下每个数据集的样本数
print("Client clean data (transformed):", [len(d) for d in client_clean_data_transformed])
print("Client poison data (transformed):", [len(d) for d in client_poison_data_transformed])
print("Test dataset (transformed) samples count:", len(test_dataset_transformed))
print("Test poison samples (transformed) count:", len(test_poison_samples_transformed))
# Out:
# Client clean data (transformed): [12665, 12089, 11263, 12183, 11800]
# Client poison data (transformed): [13665, 12089, 11263, 12183, 11800]
# Test dataset (transformed) samples count: 10000
# Test poison samples (transformed) count: 10000

# %%
from torch.utils.data import Dataset, DataLoader

# 定义一个简单的 Dataset 类，包装 (img, label) 列表
class ListDataset(Dataset):
    def __init__(self, data_list):
        self.data_list = data_list
        
    def __len__(self):
        return len(self.data_list)
    
    def __getitem__(self, index):
        return self.data_list[index]

# 对 client_clean_data_transformed，每个客户端构建一个 DataLoader（batch_size 可自行调整）
client_clean_loaders = [
    DataLoader(ListDataset(client_data), batch_size=32, shuffle=True)
    for client_data in client_clean_data_transformed
]

# 对 client_poison_data_transformed，每个客户端构建一个 DataLoader
client_poison_loaders = [
    DataLoader(ListDataset(client_data), batch_size=32, shuffle=True)
    for client_data in client_poison_data_transformed
]

# 构建测试集的 DataLoader（干净的）
test_loader = DataLoader(ListDataset(test_dataset_transformed), batch_size=128, shuffle=False)

# 构建带触发器且 label flip 的测试集 DataLoader
test_poison_loader = DataLoader(ListDataset(test_poison_samples_transformed), batch_size=128, shuffle=False)

# 检查一下每个 DataLoader 的数据量（打印长度）
print("Client clean loaders:")
for i, loader in enumerate(client_clean_loaders):
    print(f"  Client {i}: {len(loader.dataset)} samples")
    
print("Client poison loaders:")
for i, loader in enumerate(client_poison_loaders):
    print(f"  Client {i}: {len(loader.dataset)} samples")

print("Test loader:", len(test_loader.dataset))
print("Test poison loader:", len(test_poison_loader.dataset))
# Out:
# Client clean loaders:
#   Client 0: 12665 samples
#   Client 1: 12089 samples
#   Client 2: 11263 samples
#   Client 3: 12183 samples
#   Client 4: 11800 samples
# Client poison loaders:
#   Client 0: 13665 samples
#   Client 1: 12089 samples
#   Client 2: 11263 samples
#   Client 3: 12183 samples
#   Client 4: 11800 samples
# Test loader: 10000
# Test poison loader: 10000

# %% [markdown]
# ## FL train on clean dataset

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 10)
    
    def forward(self, x):
        # 将 28x28 的图像展平为 784 维向量
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def local_train(model, dataloader, epochs, device):
    model.train()
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    criterion = nn.CrossEntropyLoss()
    for epoch in range(epochs):
        for data, target in dataloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
    # 返回训练后的模型参数
    return model.state_dict()

def fed_avg(global_model, client_state_dicts, client_data_counts):
    global_state_dict = global_model.state_dict()
    # 初始化全局模型参数为零
    for key in global_state_dict.keys():
        global_state_dict[key] = torch.zeros_like(global_state_dict[key])
    total_samples = sum(client_data_counts)
    # 对每个客户端的参数按数据量权重累加
    for client_state, n_samples in zip(client_state_dicts, client_data_counts):
        weight = n_samples / total_samples
        for key in global_state_dict.keys():
            global_state_dict[key] += client_state[key] * weight
    # 更新全局模型
    global_model.load_state_dict(global_state_dict)
    return global_model

def _geometric_median(params_list, weights=None, max_iter=10, eps=1e-5):
    """
    计算给定若干张量的带权几何中值 (Geometric Median)。
    params_list: list of Tensors，长度为 N（客户端数）。
                 每个张量形状相同（对应模型的某个参数）。
    weights:     list or array of shape [N]，表示每个张量的权重(如客户端数据量)。
                 如果为 None，则默认每个客户端等权重。
    max_iter:    最大迭代次数
    eps:         防止距离为 0 的微小数，以及判断收敛阈值

    返回: 与 params_list 中张量形状相同的几何中值张量
    """
    if weights is None:
        weights = np.ones(len(params_list), dtype=np.float32)
    else:
        weights = np.array(weights, dtype=np.float32)

    # 初始值：简单用“加权平均”做几何中值的初始解
    gm = torch.zeros_like(params_list[0])
    total_w = weights.sum()
    for p, w in zip(params_list, weights):
        gm += p * (w / total_w)

    for _ in range(max_iter):
        numerator = torch.zeros_like(gm)
        denominator = 0.0

        # 计算每个客户端的贡献
        for p, w in zip(params_list, weights):
            dist = torch.norm(gm - p)  # L2 范数
            # 避免除 0
            if dist < eps:
                dist = eps

            # Weiszfeld’s Algorithm 更新
            numerator += (w / dist) * p
            denominator += (w / dist)

        new_gm = numerator / denominator

        # 若收敛则停止
        if torch.norm(new_gm - gm) < eps:
            gm = new_gm
            break
        gm = new_gm

    return gm


def fed_rfa(global_model, client_state_dicts, client_data_counts, max_iter=10, eps=1e-5):
    """
    使用 RFA (基于几何中值) 替代简单加权平均来更新 global_model
    
    client_state_dicts: List[OrderedDict]，每个客户端的模型参数
    client_data_counts: List[int]，每个客户端所拥有的数据量 (做为权重)
    max_iter, eps: 计算几何中值时的迭代上限和收敛阈值
    """
    # 提取当前全局模型参数的键
    global_state_dict = global_model.state_dict()

    # 对每个参数 key 分别计算几何中值
    for key in global_state_dict.keys():
        # 1) 收集所有客户端的对应参数
        params_list = [client_sd[key] for client_sd in client_state_dicts]

        # 2) 计算几何中值
        gm_param = _geometric_median(params_list, weights=client_data_counts,
                                     max_iter=max_iter, eps=eps)

        # 3) 将该参数赋值到 global_state_dict
        global_state_dict[key] = gm_param

    # 将更新后的参数载入全局模型
    global_model.load_state_dict(global_state_dict)
    return global_model

def _trimmed_mean(params_list, trim_ratio=0.1):
    """
    对给定的一组同形状张量 (params_list) 进行 Trimmed Mean 聚合。
    params_list: list of Tensors，形状均相同，[n, ...]，n为客户端数。
    trim_ratio: 截断比例 α，表示去掉最小 α*n 个值和最大 α*n 个值。
                例如 0.1 表示截断 10%。
    
    返回: 与输入同形状的张量，代表截断均值结果。
    """
    # 假设至少有2个客户端
    n = len(params_list)
    if n == 0:
        raise ValueError("params_list is empty.")

    # 将所有张量展平为 [n, param_size]
    # shape[0] = n， shape[1] = param_size(剩下的尺寸用 -1 表示自动推断)
    flattened = torch.stack([p.flatten() for p in params_list], dim=0)  # [n, param_size]
    n, param_size = flattened.shape[0], flattened.shape[1]

    # 计算需要截断的数量
    # 若 n*trim_ratio 不是整数，则向下取整
    trim_k = int(n * trim_ratio)
    if trim_k == 0:
        # 如果 trim_ratio 很小，可能 trim_k=0，相当于没截断
        # 这种情况可以直接返回简单平均
        return flattened.mean(dim=0).view_as(params_list[0])

    # 对每个坐标进行截断平均
    result = torch.zeros(param_size, device=flattened.device)
    for i in range(param_size):
        # 取出第 i 个坐标在所有客户端的值
        coord_values = flattened[:, i]
        # 排序
        sorted_vals, _ = torch.sort(coord_values)
        # 去掉前 trim_k 个和后 trim_k 个
        trimmed_vals = sorted_vals[trim_k:-trim_k]  # [ (n - 2*trim_k) ]
        # 计算平均
        coord_mean = trimmed_vals.mean()
        result[i] = coord_mean

    # reshape 回原来的形状
    result = result.view_as(params_list[0])
    return result


def fed_trimmed_mean(global_model, client_state_dicts, trim_ratio=0.1):
    """
    使用坐标截断平均(Trimmed Mean)替代简单加权平均来更新 global_model。
    这里没有使用 client_data_counts（等权），如果想考虑数据量差异，
    可以自行在截断前先把某些客户端重复多份或尝试其他加权思路，不过最常见用法是等权。
    
    :param global_model:       全局模型
    :param client_state_dicts: List[OrderedDict]，每个客户端的模型参数
    :param trim_ratio:         截断比例 α (如 0.1 表示截断 10%)
    """
    global_state_dict = global_model.state_dict()
    param_keys = list(global_state_dict.keys())

    # 对每个参数 key 分别做坐标截断均值
    for key in param_keys:
        params_list = [client_sd[key] for client_sd in client_state_dicts]
        # 计算截断平均
        tm_param = _trimmed_mean(params_list, trim_ratio=trim_ratio)
        # 写回 global_state_dict
        global_state_dict[key] = tm_param

    # 更新 global_model
    global_model.load_state_dict(global_state_dict)
    return global_model

# %%
def evaluate_model(model, device, clean_loader, poison_loader, n_classes=10, backdoor_target=0):
    """
    同时评估模型在干净测试集和带触发器测试集上的表现：
    
    参数:
    model: 待评估的模型。
    device: 设备（如 "cuda:0" 或 "cpu"）。
    clean_loader: 干净测试集的 DataLoader，用于计算准确率 (acc) 以及各类别准确率。
    poison_loader: 带触发器且标签翻转的测试集 DataLoader，用于计算后门攻击成功率 (ASR)。
    n_classes: 分类任务的类别数，默认为 10。
    backdoor_target: 后门目标标签（在计算 ASR 时，统计预测为该标签的比例）。
    
    返回:
    overall_acc: 干净测试集上的总体准确率（百分比）。
    class_accuracies: 各类别的准确率列表（百分比）。
    asr: 带触发器测试集上的后门攻击成功率（ASR，百分比）。
    """
    # 干净测试集评估
    model.eval()
    total = 0
    correct = 0
    class_correct = [0 for _ in range(n_classes)]
    class_total = [0 for _ in range(n_classes)]
    with torch.no_grad():
        for data, target in clean_loader:
            data, target = data.to(device), target.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            # 统计每个类别的正确预测数
            for i in range(target.size(0)):
                lbl = target[i].item()
                class_total[lbl] += 1
                if predicted[i].item() == lbl:
                    class_correct[lbl] += 1
    overall_acc = 100.0 * correct / total
    class_accuracies = [100.0 * c / t if t > 0 else 0.0 for c, t in zip(class_correct, class_total)]
    
    # 带触发器测试集评估 (ASR)
    total_poison = 0
    correct_poison = 0
    with torch.no_grad():
        for data, target in poison_loader:
            data, target = data.to(device), target.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs, 1)
            total_poison += target.size(0)
            # 这里认为如果模型预测为后门目标标签，则认为攻击成功
            correct_poison += (predicted == backdoor_target).sum().item()
    asr = 100.0 * correct_poison / total_poison

    return overall_acc, class_accuracies, asr

# 使用示例：
# 假设 clean 测试集 DataLoader 为 test_loader，
# 带触发器且 label flip 的测试集 DataLoader 为 test_poison_loader，
# 设备为 device，后门目标标签为 0

'''overall_acc, class_acc, asr = evaluate_model(model, device, test_loader, test_poison_loader, n_classes=10, backdoor_target=0)
print("Clean Test Accuracy: {:.2f}%".format(overall_acc))
for i, acc in enumerate(class_acc):
    print(f"  Class {i} Accuracy: {acc:.2f}%")
print("Backdoor Attack Success Rate (ASR): {:.2f}%".format(asr))'''
# Out:
# 'overall_acc, class_acc, asr = evaluate_model(model, device, test_loader, test_poison_loader, n_classes=10, backdoor_target=0)\nprint("Clean Test Accuracy: {:.2f}%".format(overall_acc))\nfor i, acc in enumerate(class_acc):\n    print(f"  Class {i} Accuracy: {acc:.2f}%")\nprint("Backdoor Attack Success Rate (ASR): {:.2f}%".format(asr))'

# %%
# 计算每个客户端的样本数量（使用干净数据集的数量即可）
client_data_counts = [len(loader.dataset) for loader in client_clean_loaders]
print("每个客户端数据量:", client_data_counts)

global_model_clean = SimpleNN().to(device)

for r in range(num_rounds):
    print(f"==== 第 {r+1} 轮通信 ====")
    client_state_dicts = []
    local_models = []
    
    # 遍历每个客户端进行本地训练和测试
    for c_id in range(len(client_clean_loaders)):
        local_model = SimpleNN().to(device)
        # 同步全局模型参数到客户端
        local_model.load_state_dict(global_model_clean.state_dict())
        # 如果是客户端 0，则使用含有后门数据的 DataLoader，否则使用干净数据的 DataLoader
        train_loader = client_clean_loaders[c_id]
            
        # 客户端本地训练
        local_state = local_train(local_model, train_loader, local_epochs, device)
        client_state_dicts.append(local_state)
        local_models.append(local_model)
        
        # 使用统一的测试函数评估客户端本地模型：
        # clean test: test_loader；backdoor test: test_poison_loader
        local_clean_acc, local_class_acc, local_asr = evaluate_model(
            local_model, device, test_loader, test_poison_loader)
        print(f"Client {c_id} local model test accuracy: {local_clean_acc:.2f}%")
        print(f"Backdoor Attack Success Rate (ASR): {local_asr:.2f}%")
        for i in range(10):
            print(f"  Class {i} accuracy: {local_class_acc[i]:.2f}%")
    
    # 使用数据量加权的 FedAvg 聚合各客户端模型
    global_model_clean = fed_rfa(global_model_clean, client_state_dicts, client_data_counts)
    
    # 全局模型测试（同时评估 clean accuracy 和 ASR）
    global_clean_acc, global_clean_class_acc, global_clean_asr = evaluate_model(
        global_model_clean, device, test_loader, test_poison_loader)
    print(f"Global model after round {r+1} test accuracy: {global_clean_acc:.2f}%")
    print(f"Backdoor Attack Success Rate (ASR): {global_clean_asr:.2f}%")
    for i in range(10):
        print(f"  Global model Class {i} accuracy: {global_clean_class_acc[i]:.2f}%")
    print("\n")
# Out:
# 每个客户端数据量: [12665, 12089, 11263, 12183, 11800]
# ==== 第 1 轮通信 ====
# Client 0 local model test accuracy: 21.11%
# Backdoor Attack Success Rate (ASR): 56.81%
#   Class 0 accuracy: 99.69%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.88%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.71%
#   Class 3 accuracy: 98.02%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.56%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.88%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.74%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.22%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.29%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.77%
#   Class 9 accuracy: 95.84%
# Global model after round 1 test accuracy: 53.63%
# Backdoor Attack Success Rate (ASR): 11.46%
#   Global model Class 0 accuracy: 75.92%
#   Global model Class 1 accuracy: 85.99%
#   Global model Class 2 accuracy: 16.38%
#   Global model Class 3 accuracy: 77.03%
#   Global model Class 4 accuracy: 1.53%
#   Global model Class 5 accuracy: 8.97%
#   Global model Class 6 accuracy: 90.81%
#   Global model Class 7 accuracy: 72.86%
#   Global model Class 8 accuracy: 28.03%
#   Global model Class 9 accuracy: 70.27%
#
#
# ==== 第 2 轮通信 ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 61.14%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.89%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.19%
#   Class 3 accuracy: 97.62%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.53%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.54%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.72%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 98.93%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.20%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 95.89%
#   Class 9 accuracy: 97.72%
# Global model after round 2 test accuracy: 62.86%
# Backdoor Attack Success Rate (ASR): 16.06%
#   Global model Class 0 accuracy: 95.61%
#   Global model Class 1 accuracy: 97.80%
#   Global model Class 2 accuracy: 38.57%
#   Global model Class 3 accuracy: 78.22%
#   Global model Class 4 accuracy: 15.17%
#   Global model Class 5 accuracy: 17.15%
#   Global model Class 6 accuracy: 88.31%
#   Global model Class 7 accuracy: 83.85%
#   Global model Class 8 accuracy: 49.90%
#   Global model Class 9 accuracy: 55.00%
#
#
# ==== 第 3 轮通信 ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 58.98%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.93%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.19%
#   Class 3 accuracy: 98.02%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.52%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.75%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.22%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.32%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.54%
#   Class 9 accuracy: 97.32%
# Global model after round 3 test accuracy: 66.73%
# Backdoor Attack Success Rate (ASR): 15.42%
#   Global model Class 0 accuracy: 97.45%
#   Global model Class 1 accuracy: 98.85%
#   Global model Class 2 accuracy: 48.74%
#   Global model Class 3 accuracy: 78.22%
#   Global model Class 4 accuracy: 40.84%
#   Global model Class 5 accuracy: 20.63%
#   Global model Class 6 accuracy: 87.27%
#   Global model Class 7 accuracy: 86.38%
#   Global model Class 8 accuracy: 51.33%
#   Global model Class 9 accuracy: 48.96%
#
#
# ==== 第 4 轮通信 ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 59.46%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.88%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.19%
#   Class 3 accuracy: 97.52%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.52%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.75%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.22%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.32%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.74%
#   Class 9 accuracy: 97.13%
# Global model after round 4 test accuracy: 70.05%
# Backdoor Attack Success Rate (ASR): 14.63%
#   Global model Class 0 accuracy: 97.96%
#   Global model Class 1 accuracy: 98.94%
#   Global model Class 2 accuracy: 52.13%
#   Global model Class 3 accuracy: 78.42%
#   Global model Class 4 accuracy: 56.72%
#   Global model Class 5 accuracy: 25.67%
#   Global model Class 6 accuracy: 88.83%
#   Global model Class 7 accuracy: 86.96%
#   Global model Class 8 accuracy: 56.26%
#   Global model Class 9 accuracy: 50.84%
#
#
# ==== 第 5 轮通信 ====
# Client 0 local model test accuracy: 21.25%
# Backdoor Attack Success Rate (ASR): 58.26%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 1.17%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.91%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.38%
#   Class 3 accuracy: 97.52%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.51%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.32%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.76%
# Backdoor Attack Success Rate (ASR): 0.04%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.33%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.56%
#   Class 9 accuracy: 96.43%
# Global model after round 5 test accuracy: 71.96%
# Backdoor Attack Success Rate (ASR): 13.99%
#   Global model Class 0 accuracy: 98.27%
#   Global model Class 1 accuracy: 98.85%
#   Global model Class 2 accuracy: 54.75%
#   Global model Class 3 accuracy: 79.41%
#   Global model Class 4 accuracy: 66.40%
#   Global model Class 5 accuracy: 29.04%
#   Global model Class 6 accuracy: 89.56%
#   Global model Class 7 accuracy: 87.84%
#   Global model Class 8 accuracy: 60.68%
#   Global model Class 9 accuracy: 47.67%
#
#
# ==== 第 6 轮通信 ====
# Client 0 local model test accuracy: 21.46%
# Backdoor Attack Success Rate (ASR): 58.54%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.20%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 3.02%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.94%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.38%
#   Class 3 accuracy: 97.82%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.53%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.54%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.79%
# Backdoor Attack Success Rate (ASR): 0.09%
#   Class 0 accuracy: 0.31%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.34%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 99.08%
#   Class 9 accuracy: 96.04%
# Global model after round 6 test accuracy: 73.31%
# Backdoor Attack Success Rate (ASR): 13.30%
#   Global model Class 0 accuracy: 98.27%
#   Global model Class 1 accuracy: 98.68%
#   Global model Class 2 accuracy: 55.33%
#   Global model Class 3 accuracy: 80.20%
#   Global model Class 4 accuracy: 71.89%
#   Global model Class 5 accuracy: 33.18%
#   Global model Class 6 accuracy: 90.81%
#   Global model Class 7 accuracy: 88.33%
#   Global model Class 8 accuracy: 63.76%
#   Global model Class 9 accuracy: 46.18%
#
#
# ==== 第 7 轮通信 ====
# Client 0 local model test accuracy: 21.87%
# Backdoor Attack Success Rate (ASR): 59.64%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.51%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 6.71%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.98%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.29%
#   Class 3 accuracy: 98.32%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.54%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.65%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.88%
# Backdoor Attack Success Rate (ASR): 0.20%
#   Class 0 accuracy: 0.92%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.33%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.10%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 96.71%
#   Class 9 accuracy: 98.12%
# Global model after round 7 test accuracy: 75.12%
# Backdoor Attack Success Rate (ASR): 13.18%
#   Global model Class 0 accuracy: 98.57%
#   Global model Class 1 accuracy: 98.50%
#   Global model Class 2 accuracy: 56.40%
#   Global model Class 3 accuracy: 81.78%
#   Global model Class 4 accuracy: 73.22%
#   Global model Class 5 accuracy: 40.47%
#   Global model Class 6 accuracy: 91.13%
#   Global model Class 7 accuracy: 88.81%
#   Global model Class 8 accuracy: 62.94%
#   Global model Class 9 accuracy: 53.62%
#
#
# ==== 第 8 轮通信 ====
# Client 0 local model test accuracy: 22.40%
# Backdoor Attack Success Rate (ASR): 58.42%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 1.43%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 10.80%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.20%
# Client 1 local model test accuracy: 19.97%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.09%
#   Class 3 accuracy: 98.42%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.58%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.10%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.98%
# Backdoor Attack Success Rate (ASR): 0.37%
#   Class 0 accuracy: 2.24%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.42%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.31%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.36%
#   Class 9 accuracy: 97.22%
# Global model after round 8 test accuracy: 75.83%
# Backdoor Attack Success Rate (ASR): 13.03%
#   Global model Class 0 accuracy: 98.57%
#   Global model Class 1 accuracy: 98.50%
#   Global model Class 2 accuracy: 57.56%
#   Global model Class 3 accuracy: 82.48%
#   Global model Class 4 accuracy: 76.37%
#   Global model Class 5 accuracy: 40.70%
#   Global model Class 6 accuracy: 91.44%
#   Global model Class 7 accuracy: 88.81%
#   Global model Class 8 accuracy: 64.48%
#   Global model Class 9 accuracy: 53.72%
#
#
# ==== 第 9 轮通信 ====
# Client 0 local model test accuracy: 23.23%
# Backdoor Attack Success Rate (ASR): 57.92%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 2.85%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.21%
#   Class 7 accuracy: 16.73%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.79%
# Client 1 local model test accuracy: 19.99%
# Backdoor Attack Success Rate (ASR): 0.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.00%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.54%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.39%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 20.16%
# Backdoor Attack Success Rate (ASR): 0.54%
#   Class 0 accuracy: 3.98%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.43%
# Backdoor Attack Success Rate (ASR): 0.02%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.31%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.56%
#   Class 9 accuracy: 97.13%
# Global model after round 9 test accuracy: 76.14%
# Backdoor Attack Success Rate (ASR): 12.87%
#   Global model Class 0 accuracy: 98.78%
#   Global model Class 1 accuracy: 98.41%
#   Global model Class 2 accuracy: 56.49%
#   Global model Class 3 accuracy: 83.17%
#   Global model Class 4 accuracy: 78.41%
#   Global model Class 5 accuracy: 41.82%
#   Global model Class 6 accuracy: 91.65%
#   Global model Class 7 accuracy: 89.79%
#   Global model Class 8 accuracy: 65.91%
#   Global model Class 9 accuracy: 51.54%
#
#
# ==== 第 10 轮通信 ====
# Client 0 local model test accuracy: 24.36%
# Backdoor Attack Success Rate (ASR): 52.64%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.19%
#   Class 3 accuracy: 0.10%
#   Class 4 accuracy: 6.11%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.31%
#   Class 7 accuracy: 23.64%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 1.39%
# Client 1 local model test accuracy: 19.96%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.51%
#   Class 3 accuracy: 98.91%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.58%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.09%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 98.77%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 20.18%
# Backdoor Attack Success Rate (ASR): 0.57%
#   Class 0 accuracy: 4.08%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.39%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.42%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.43%
#   Class 9 accuracy: 97.62%
# Global model after round 10 test accuracy: 77.11%
# Backdoor Attack Success Rate (ASR): 12.45%
#   Global model Class 0 accuracy: 98.57%
#   Global model Class 1 accuracy: 98.50%
#   Global model Class 2 accuracy: 57.56%
#   Global model Class 3 accuracy: 84.36%
#   Global model Class 4 accuracy: 78.72%
#   Global model Class 5 accuracy: 45.85%
#   Global model Class 6 accuracy: 92.07%
#   Global model Class 7 accuracy: 90.08%
#   Global model Class 8 accuracy: 64.17%
#   Global model Class 9 accuracy: 56.10%

# %% [markdown]
# ## FL train on poisoned dataset

# %%
# 计算每个客户端的样本数量（使用投毒数据集的数量即可）
client_poison_data_counts = [len(loader.dataset) for loader in client_poison_loaders]
print("每个客户端投毒数据量:", client_poison_data_counts)

# 新建一个全局模型，用于投毒数据训练，确保不覆盖之前的 global_model_clean
global_model_poison = SimpleNN().to(device)

for r in range(num_rounds):
    print(f"==== 第 {r+1} 轮通信（投毒数据训练） ====")
    client_state_dicts = []
    local_models = []
    
    # 遍历每个客户端进行本地训练和测试（均使用投毒数据）
    for c_id in range(len(client_poison_loaders)):
        local_model = SimpleNN().to(device)
        # 同步全局投毒模型参数到客户端
        local_model.load_state_dict(global_model_poison.state_dict())
        
        # 每个客户端均使用投毒数据进行本地训练
        train_loader = client_poison_loaders[c_id]
            
        # 客户端本地训练
        local_state = local_train(local_model, train_loader, local_epochs, device)
        client_state_dicts.append(local_state)
        local_models.append(local_model)
        
        # 使用统一测试函数评估客户端本地模型：
        # 干净测试集: test_loader；带触发器且 label flip 的测试集: test_poison_loader
        local_clean_acc, local_class_acc, local_asr = evaluate_model(
            local_model, device, test_loader, test_poison_loader)
        print(f"Client {c_id} local model test accuracy: {local_clean_acc:.2f}%")
        print(f"Backdoor Attack Success Rate (ASR): {local_asr:.2f}%")
        for i in range(10):
            print(f"  Class {i} accuracy: {local_class_acc[i]:.2f}%")
    
    # 使用数据量加权的 FedAvg 聚合各客户端模型，更新投毒全局模型
    global_model_poison = fed_rfa(global_model_poison, client_state_dicts, client_poison_data_counts)
    
    # 全局模型测试（同时评估干净准确率和 ASR）
    global_clean_acc, global_clean_class_acc, global_clean_asr = evaluate_model(
        global_model_poison, device, test_loader, test_poison_loader)
    print(f"Global model (poison) after round {r+1} test accuracy: {global_clean_acc:.2f}%")
    print(f"Backdoor Attack Success Rate (ASR): {global_clean_asr:.2f}%")
    for i in range(10):
        print(f"  Global model Class {i} accuracy: {global_clean_class_acc[i]:.2f}%")
    print("\n")
# Out:
# 每个客户端投毒数据量: [13665, 12089, 11263, 12183, 11800]
# ==== 第 1 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 89.37%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.88%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.58%
#   Class 3 accuracy: 97.13%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.53%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.54%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.73%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.37%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.28%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.54%
#   Class 9 accuracy: 96.93%
# Global model (poison) after round 1 test accuracy: 48.53%
# Backdoor Attack Success Rate (ASR): 29.09%
#   Global model Class 0 accuracy: 84.59%
#   Global model Class 1 accuracy: 99.56%
#   Global model Class 2 accuracy: 37.40%
#   Global model Class 3 accuracy: 48.12%
#   Global model Class 4 accuracy: 59.78%
#   Global model Class 5 accuracy: 6.39%
#   Global model Class 6 accuracy: 49.16%
#   Global model Class 7 accuracy: 75.00%
#   Global model Class 8 accuracy: 13.35%
#   Global model Class 9 accuracy: 0.59%
#
#
# ==== 第 2 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 94.14%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.95%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.00%
#   Class 3 accuracy: 98.42%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.58%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.10%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.76%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.18%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 95.48%
#   Class 9 accuracy: 97.92%
# Global model (poison) after round 2 test accuracy: 60.33%
# Backdoor Attack Success Rate (ASR): 53.70%
#   Global model Class 0 accuracy: 95.71%
#   Global model Class 1 accuracy: 99.47%
#   Global model Class 2 accuracy: 50.78%
#   Global model Class 3 accuracy: 66.14%
#   Global model Class 4 accuracy: 70.37%
#   Global model Class 5 accuracy: 13.90%
#   Global model Class 6 accuracy: 75.16%
#   Global model Class 7 accuracy: 84.82%
#   Global model Class 8 accuracy: 22.07%
#   Global model Class 9 accuracy: 15.06%
#
#
# ==== 第 3 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 98.41%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.95%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.48%
#   Class 3 accuracy: 97.92%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.62%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.55%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.76%
# Backdoor Attack Success Rate (ASR): 0.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.26%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 96.82%
#   Class 9 accuracy: 97.42%
# Global model (poison) after round 3 test accuracy: 67.07%
# Backdoor Attack Success Rate (ASR): 64.50%
#   Global model Class 0 accuracy: 97.24%
#   Global model Class 1 accuracy: 99.38%
#   Global model Class 2 accuracy: 56.20%
#   Global model Class 3 accuracy: 72.18%
#   Global model Class 4 accuracy: 71.89%
#   Global model Class 5 accuracy: 23.54%
#   Global model Class 6 accuracy: 84.13%
#   Global model Class 7 accuracy: 86.77%
#   Global model Class 8 accuracy: 35.32%
#   Global model Class 9 accuracy: 35.58%
#
#
# ==== 第 4 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 96.59%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.95%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.48%
#   Class 3 accuracy: 97.92%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.58%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.10%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.77%
# Backdoor Attack Success Rate (ASR): 0.14%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.32%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.36%
#   Class 9 accuracy: 96.53%
# Global model (poison) after round 4 test accuracy: 70.72%
# Backdoor Attack Success Rate (ASR): 66.23%
#   Global model Class 0 accuracy: 97.45%
#   Global model Class 1 accuracy: 99.21%
#   Global model Class 2 accuracy: 56.69%
#   Global model Class 3 accuracy: 76.14%
#   Global model Class 4 accuracy: 75.25%
#   Global model Class 5 accuracy: 26.46%
#   Global model Class 6 accuracy: 89.46%
#   Global model Class 7 accuracy: 87.94%
#   Global model Class 8 accuracy: 47.33%
#   Global model Class 9 accuracy: 43.61%
#
#
# ==== 第 5 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.12%
# Backdoor Attack Success Rate (ASR): 98.60%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.96%
# Backdoor Attack Success Rate (ASR): 0.02%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 98.26%
#   Class 3 accuracy: 97.23%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.57%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 98.88%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.79%
# Backdoor Attack Success Rate (ASR): 0.51%
#   Class 0 accuracy: 0.20%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.42%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.31%
# Backdoor Attack Success Rate (ASR): 0.10%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.64%
#   Class 9 accuracy: 97.13%
# Global model (poison) after round 5 test accuracy: 72.84%
# Backdoor Attack Success Rate (ASR): 72.32%
#   Global model Class 0 accuracy: 97.96%
#   Global model Class 1 accuracy: 99.21%
#   Global model Class 2 accuracy: 56.30%
#   Global model Class 3 accuracy: 77.43%
#   Global model Class 4 accuracy: 76.88%
#   Global model Class 5 accuracy: 31.05%
#   Global model Class 6 accuracy: 90.92%
#   Global model Class 7 accuracy: 87.84%
#   Global model Class 8 accuracy: 51.95%
#   Global model Class 9 accuracy: 51.83%
#
#
# ==== 第 6 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.14%
# Backdoor Attack Success Rate (ASR): 99.81%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.19%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.98%
# Backdoor Attack Success Rate (ASR): 0.10%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.58%
#   Class 3 accuracy: 98.12%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.59%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.22%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.84%
# Backdoor Attack Success Rate (ASR): 1.04%
#   Class 0 accuracy: 0.61%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.36%
# Backdoor Attack Success Rate (ASR): 0.40%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.21%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 99.08%
#   Class 9 accuracy: 96.04%
# Global model (poison) after round 6 test accuracy: 73.84%
# Backdoor Attack Success Rate (ASR): 78.36%
#   Global model Class 0 accuracy: 98.16%
#   Global model Class 1 accuracy: 99.21%
#   Global model Class 2 accuracy: 55.62%
#   Global model Class 3 accuracy: 80.50%
#   Global model Class 4 accuracy: 77.90%
#   Global model Class 5 accuracy: 33.41%
#   Global model Class 6 accuracy: 91.02%
#   Global model Class 7 accuracy: 87.94%
#   Global model Class 8 accuracy: 56.88%
#   Global model Class 9 accuracy: 51.14%
#
#
# ==== 第 7 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.19%
# Backdoor Attack Success Rate (ASR): 100.00%
#   Class 0 accuracy: 100.00%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.49%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 20.00%
# Backdoor Attack Success Rate (ASR): 0.28%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.58%
#   Class 3 accuracy: 98.32%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.60%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 99.33%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.90%
# Backdoor Attack Success Rate (ASR): 1.84%
#   Class 0 accuracy: 1.12%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.43%
# Backdoor Attack Success Rate (ASR): 1.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.52%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.36%
#   Class 9 accuracy: 97.13%
# Global model (poison) after round 7 test accuracy: 74.71%
# Backdoor Attack Success Rate (ASR): 82.71%
#   Global model Class 0 accuracy: 98.27%
#   Global model Class 1 accuracy: 98.94%
#   Global model Class 2 accuracy: 55.33%
#   Global model Class 3 accuracy: 81.78%
#   Global model Class 4 accuracy: 78.51%
#   Global model Class 5 accuracy: 36.66%
#   Global model Class 6 accuracy: 90.81%
#   Global model Class 7 accuracy: 88.13%
#   Global model Class 8 accuracy: 56.98%
#   Global model Class 9 accuracy: 55.40%
#
#
# ==== 第 8 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.39%
# Backdoor Attack Success Rate (ASR): 98.81%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 2.53%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.94%
# Backdoor Attack Success Rate (ASR): 1.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.71%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.58%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 98.99%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.97%
# Backdoor Attack Success Rate (ASR): 2.81%
#   Class 0 accuracy: 1.84%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.43%
# Backdoor Attack Success Rate (ASR): 2.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.73%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.05%
#   Class 9 accuracy: 97.22%
# Global model (poison) after round 8 test accuracy: 75.50%
# Backdoor Attack Success Rate (ASR): 81.15%
#   Global model Class 0 accuracy: 98.06%
#   Global model Class 1 accuracy: 98.94%
#   Global model Class 2 accuracy: 53.88%
#   Global model Class 3 accuracy: 84.26%
#   Global model Class 4 accuracy: 80.04%
#   Global model Class 5 accuracy: 40.58%
#   Global model Class 6 accuracy: 91.86%
#   Global model Class 7 accuracy: 88.04%
#   Global model Class 8 accuracy: 57.08%
#   Global model Class 9 accuracy: 56.49%
#
#
# ==== 第 9 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.48%
# Backdoor Attack Success Rate (ASR): 99.74%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 3.31%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 20.01%
# Backdoor Attack Success Rate (ASR): 1.46%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.19%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.61%
# Backdoor Attack Success Rate (ASR): 0.07%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 99.33%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 20.03%
# Backdoor Attack Success Rate (ASR): 3.80%
#   Class 0 accuracy: 2.45%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.51%
# Backdoor Attack Success Rate (ASR): 3.07%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.84%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.46%
#   Class 9 accuracy: 97.42%
# Global model (poison) after round 9 test accuracy: 76.48%
# Backdoor Attack Success Rate (ASR): 82.83%
#   Global model Class 0 accuracy: 98.27%
#   Global model Class 1 accuracy: 98.94%
#   Global model Class 2 accuracy: 54.26%
#   Global model Class 3 accuracy: 84.75%
#   Global model Class 4 accuracy: 79.53%
#   Global model Class 5 accuracy: 43.05%
#   Global model Class 6 accuracy: 92.17%
#   Global model Class 7 accuracy: 88.23%
#   Global model Class 8 accuracy: 60.37%
#   Global model Class 9 accuracy: 59.76%
#
#
# ==== 第 10 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.60%
# Backdoor Attack Success Rate (ASR): 99.98%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 4.57%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 20.07%
# Backdoor Attack Success Rate (ASR): 2.11%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.97%
#   Class 3 accuracy: 98.51%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.57%
# Backdoor Attack Success Rate (ASR): 0.17%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.49%
#   Class 5 accuracy: 98.65%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 20.08%
# Backdoor Attack Success Rate (ASR): 4.78%
#   Class 0 accuracy: 3.06%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.46%
# Backdoor Attack Success Rate (ASR): 4.39%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.94%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.87%
#   Class 9 accuracy: 96.43%
# Global model (poison) after round 10 test accuracy: 76.62%
# Backdoor Attack Success Rate (ASR): 85.91%
#   Global model Class 0 accuracy: 98.37%
#   Global model Class 1 accuracy: 98.77%
#   Global model Class 2 accuracy: 55.43%
#   Global model Class 3 accuracy: 84.65%
#   Global model Class 4 accuracy: 81.26%
#   Global model Class 5 accuracy: 40.92%
#   Global model Class 6 accuracy: 92.59%
#   Global model Class 7 accuracy: 88.04%
#   Global model Class 8 accuracy: 62.11%
#   Global model Class 9 accuracy: 58.47%

# %%
# 计算每个客户端的样本数量（使用投毒数据集的数量即可）
client_poison_data_counts = [len(loader.dataset) for loader in client_poison_loaders]
print("每个客户端投毒数据量:", client_poison_data_counts)

# 新建一个全局模型，用于投毒数据训练，确保不覆盖之前的 global_model_clean
global_model_poison = SimpleNN().to(device)

for r in range(num_rounds):
    print(f"==== 第 {r+1} 轮通信（投毒数据训练） ====")
    client_state_dicts = []
    local_models = []
    
    # 遍历每个客户端进行本地训练和测试（均使用投毒数据）
    for c_id in range(len(client_poison_loaders)):
        local_model = SimpleNN().to(device)
        # 同步全局投毒模型参数到客户端
        local_model.load_state_dict(global_model_poison.state_dict())
        
        # 每个客户端均使用投毒数据进行本地训练
        train_loader = client_poison_loaders[c_id]
            
        # 客户端本地训练
        local_state = local_train(local_model, train_loader, local_epochs, device)
        client_state_dicts.append(local_state)
        local_models.append(local_model)
        
        # 使用统一测试函数评估客户端本地模型：
        # 干净测试集: test_loader；带触发器且 label flip 的测试集: test_poison_loader
        local_clean_acc, local_class_acc, local_asr = evaluate_model(
            local_model, device, test_loader, test_poison_loader)
        print(f"Client {c_id} local model test accuracy: {local_clean_acc:.2f}%")
        print(f"Backdoor Attack Success Rate (ASR): {local_asr:.2f}%")
        for i in range(10):
            print(f"  Class {i} accuracy: {local_class_acc[i]:.2f}%")
    
    # 使用数据量加权的 FedAvg 聚合各客户端模型，更新投毒全局模型
    global_model_poison = fed_trimmed_mean(global_model_poison, client_state_dicts, trim_ratio=0.1)
    
    # 全局模型测试（同时评估干净准确率和 ASR）
    global_clean_acc, global_clean_class_acc, global_clean_asr = evaluate_model(
        global_model_poison, device, test_loader, test_poison_loader)
    print(f"Global model (poison) after round {r+1} test accuracy: {global_clean_acc:.2f}%")
    print(f"Backdoor Attack Success Rate (ASR): {global_clean_asr:.2f}%")
    for i in range(10):
        print(f"  Global model Class {i} accuracy: {global_clean_class_acc[i]:.2f}%")
    print("\n")
# Out:
# 每个客户端投毒数据量: [13665, 12089, 11263, 12183, 11800]
# ==== 第 1 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.13%
# Backdoor Attack Success Rate (ASR): 90.97%
#   Class 0 accuracy: 99.90%
#   Class 1 accuracy: 99.91%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.67%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 93.60%
#   Class 3 accuracy: 99.11%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.56%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 98.77%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.75%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.17%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 95.59%
#   Class 9 accuracy: 97.72%
# Global model (poison) after round 1 test accuracy: 46.22%
# Backdoor Attack Success Rate (ASR): 65.22%
#   Global model Class 0 accuracy: 82.04%
#   Global model Class 1 accuracy: 94.19%
#   Global model Class 2 accuracy: 4.26%
#   Global model Class 3 accuracy: 31.19%
#   Global model Class 4 accuracy: 65.58%
#   Global model Class 5 accuracy: 8.74%
#   Global model Class 6 accuracy: 59.71%
#   Global model Class 7 accuracy: 72.37%
#   Global model Class 8 accuracy: 14.58%
#   Global model Class 9 accuracy: 20.81%
#
#
# ==== 第 2 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.13%
# Backdoor Attack Success Rate (ASR): 94.23%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.90%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.29%
#   Class 3 accuracy: 97.62%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.57%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.19%
#   Class 5 accuracy: 98.99%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.73%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.03%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.18%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 95.89%
#   Class 9 accuracy: 97.52%
# Global model (poison) after round 2 test accuracy: 65.90%
# Backdoor Attack Success Rate (ASR): 44.80%
#   Global model Class 0 accuracy: 81.33%
#   Global model Class 1 accuracy: 97.89%
#   Global model Class 2 accuracy: 29.46%
#   Global model Class 3 accuracy: 54.16%
#   Global model Class 4 accuracy: 81.16%
#   Global model Class 5 accuracy: 55.04%
#   Global model Class 6 accuracy: 77.97%
#   Global model Class 7 accuracy: 85.51%
#   Global model Class 8 accuracy: 47.54%
#   Global model Class 9 accuracy: 45.00%
#
#
# ==== 第 3 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.13%
# Backdoor Attack Success Rate (ASR): 95.51%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.92%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.00%
#   Class 3 accuracy: 98.12%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.59%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 99.10%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.76%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.42%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.28%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.13%
#   Class 9 accuracy: 97.32%
# Global model (poison) after round 3 test accuracy: 71.86%
# Backdoor Attack Success Rate (ASR): 36.70%
#   Global model Class 0 accuracy: 76.22%
#   Global model Class 1 accuracy: 97.53%
#   Global model Class 2 accuracy: 46.61%
#   Global model Class 3 accuracy: 62.38%
#   Global model Class 4 accuracy: 85.85%
#   Global model Class 5 accuracy: 69.51%
#   Global model Class 6 accuracy: 77.35%
#   Global model Class 7 accuracy: 85.80%
#   Global model Class 8 accuracy: 59.86%
#   Global model Class 9 accuracy: 54.71%
#
#
# ==== 第 4 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.13%
# Backdoor Attack Success Rate (ASR): 99.48%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.97%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.38%
#   Class 3 accuracy: 98.22%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.53%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.74%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.12%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.29%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.33%
#   Class 9 accuracy: 97.22%
# Global model (poison) after round 4 test accuracy: 75.16%
# Backdoor Attack Success Rate (ASR): 42.16%
#   Global model Class 0 accuracy: 80.20%
#   Global model Class 1 accuracy: 97.44%
#   Global model Class 2 accuracy: 53.10%
#   Global model Class 3 accuracy: 71.39%
#   Global model Class 4 accuracy: 86.97%
#   Global model Class 5 accuracy: 69.17%
#   Global model Class 6 accuracy: 80.27%
#   Global model Class 7 accuracy: 85.80%
#   Global model Class 8 accuracy: 67.97%
#   Global model Class 9 accuracy: 56.59%
#
#
# ==== 第 5 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.13%
# Backdoor Attack Success Rate (ASR): 100.00%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.92%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.32%
#   Class 3 accuracy: 98.81%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.55%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.49%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.78%
# Backdoor Attack Success Rate (ASR): 0.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.38%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.46%
#   Class 9 accuracy: 97.03%
# Global model (poison) after round 5 test accuracy: 76.35%
# Backdoor Attack Success Rate (ASR): 46.62%
#   Global model Class 0 accuracy: 83.37%
#   Global model Class 1 accuracy: 96.65%
#   Global model Class 2 accuracy: 53.78%
#   Global model Class 3 accuracy: 78.22%
#   Global model Class 4 accuracy: 88.39%
#   Global model Class 5 accuracy: 64.13%
#   Global model Class 6 accuracy: 82.05%
#   Global model Class 7 accuracy: 85.80%
#   Global model Class 8 accuracy: 72.07%
#   Global model Class 9 accuracy: 56.10%
#
#
# ==== 第 6 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.14%
# Backdoor Attack Success Rate (ASR): 99.68%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.94%
# Backdoor Attack Success Rate (ASR): 0.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.61%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.61%
# Backdoor Attack Success Rate (ASR): 0.00%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 98.98%
#   Class 5 accuracy: 99.66%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.78%
# Backdoor Attack Success Rate (ASR): 0.06%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.48%
#   Class 7 accuracy: 99.71%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.34%
# Backdoor Attack Success Rate (ASR): 0.21%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.10%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.67%
#   Class 9 accuracy: 96.33%
# Global model (poison) after round 6 test accuracy: 77.25%
# Backdoor Attack Success Rate (ASR): 48.93%
#   Global model Class 0 accuracy: 83.78%
#   Global model Class 1 accuracy: 96.65%
#   Global model Class 2 accuracy: 55.33%
#   Global model Class 3 accuracy: 80.40%
#   Global model Class 4 accuracy: 87.98%
#   Global model Class 5 accuracy: 67.71%
#   Global model Class 6 accuracy: 81.32%
#   Global model Class 7 accuracy: 86.48%
#   Global model Class 8 accuracy: 73.51%
#   Global model Class 9 accuracy: 56.69%
#
#
# ==== 第 7 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.19%
# Backdoor Attack Success Rate (ASR): 99.75%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.31%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.29%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.98%
# Backdoor Attack Success Rate (ASR): 0.06%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.58%
#   Class 3 accuracy: 98.12%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.56%
# Backdoor Attack Success Rate (ASR): 0.01%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.49%
#   Class 5 accuracy: 98.54%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.78%
# Backdoor Attack Success Rate (ASR): 0.20%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.58%
#   Class 7 accuracy: 99.61%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.36%
# Backdoor Attack Success Rate (ASR): 0.92%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.21%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.43%
#   Class 9 accuracy: 97.62%
# Global model (poison) after round 7 test accuracy: 78.32%
# Backdoor Attack Success Rate (ASR): 53.09%
#   Global model Class 0 accuracy: 87.04%
#   Global model Class 1 accuracy: 96.92%
#   Global model Class 2 accuracy: 58.91%
#   Global model Class 3 accuracy: 81.39%
#   Global model Class 4 accuracy: 87.07%
#   Global model Class 5 accuracy: 66.48%
#   Global model Class 6 accuracy: 82.99%
#   Global model Class 7 accuracy: 86.09%
#   Global model Class 8 accuracy: 72.79%
#   Global model Class 9 accuracy: 60.65%
#
#
# ==== 第 8 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.27%
# Backdoor Attack Success Rate (ASR): 99.37%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.71%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.68%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.99%
# Backdoor Attack Success Rate (ASR): 0.23%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.19%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.56%
# Backdoor Attack Success Rate (ASR): 0.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.59%
#   Class 5 accuracy: 98.43%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.78%
# Backdoor Attack Success Rate (ASR): 0.47%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.48%
#   Class 7 accuracy: 99.71%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.46%
# Backdoor Attack Success Rate (ASR): 1.55%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.42%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 98.56%
#   Class 9 accuracy: 97.22%
# Global model (poison) after round 8 test accuracy: 78.54%
# Backdoor Attack Success Rate (ASR): 53.98%
#   Global model Class 0 accuracy: 87.86%
#   Global model Class 1 accuracy: 97.09%
#   Global model Class 2 accuracy: 58.62%
#   Global model Class 3 accuracy: 82.38%
#   Global model Class 4 accuracy: 87.47%
#   Global model Class 5 accuracy: 65.70%
#   Global model Class 6 accuracy: 83.30%
#   Global model Class 7 accuracy: 86.67%
#   Global model Class 8 accuracy: 73.20%
#   Global model Class 9 accuracy: 60.16%
#
#
# ==== 第 9 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.40%
# Backdoor Attack Success Rate (ASR): 99.66%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 1.32%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 1.36%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 20.02%
# Backdoor Attack Success Rate (ASR): 0.50%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 97.87%
#   Class 3 accuracy: 98.02%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.60%
# Backdoor Attack Success Rate (ASR): 0.04%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 99.22%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.80%
# Backdoor Attack Success Rate (ASR): 1.08%
#   Class 0 accuracy: 0.20%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.48%
#   Class 7 accuracy: 99.71%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.42%
# Backdoor Attack Success Rate (ASR): 2.45%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.42%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 97.54%
#   Class 9 accuracy: 97.82%
# Global model (poison) after round 9 test accuracy: 79.50%
# Backdoor Attack Success Rate (ASR): 56.90%
#   Global model Class 0 accuracy: 88.88%
#   Global model Class 1 accuracy: 97.18%
#   Global model Class 2 accuracy: 60.85%
#   Global model Class 3 accuracy: 81.98%
#   Global model Class 4 accuracy: 86.86%
#   Global model Class 5 accuracy: 68.39%
#   Global model Class 6 accuracy: 83.92%
#   Global model Class 7 accuracy: 86.28%
#   Global model Class 8 accuracy: 73.82%
#   Global model Class 9 accuracy: 64.12%
#
#
# ==== 第 10 轮通信（投毒数据训练） ====
# Client 0 local model test accuracy: 21.57%
# Backdoor Attack Success Rate (ASR): 99.99%
#   Class 0 accuracy: 99.80%
#   Class 1 accuracy: 100.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 2.34%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 2.04%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 19.94%
# Backdoor Attack Success Rate (ASR): 1.44%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 96.22%
#   Class 3 accuracy: 98.91%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.10%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 18.61%
# Backdoor Attack Success Rate (ASR): 0.16%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 99.29%
#   Class 5 accuracy: 99.33%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 19.81%
# Backdoor Attack Success Rate (ASR): 1.52%
#   Class 0 accuracy: 0.31%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.69%
#   Class 7 accuracy: 99.51%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 4 local model test accuracy: 19.44%
# Backdoor Attack Success Rate (ASR): 3.07%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.73%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 99.28%
#   Class 9 accuracy: 96.04%
# Global model (poison) after round 10 test accuracy: 79.26%
# Backdoor Attack Success Rate (ASR): 59.70%
#   Global model Class 0 accuracy: 89.49%
#   Global model Class 1 accuracy: 96.21%
#   Global model Class 2 accuracy: 57.75%
#   Global model Class 3 accuracy: 83.86%
#   Global model Class 4 accuracy: 87.58%
#   Global model Class 5 accuracy: 67.71%
#   Global model Class 6 accuracy: 84.97%
#   Global model Class 7 accuracy: 86.67%
#   Global model Class 8 accuracy: 76.08%
#   Global model Class 9 accuracy: 59.86%

# %% [markdown]
# ## Compare

# %%
# 分别评估 global_model_clean 和 global_model_poison
clean_acc_clean, class_acc_clean, asr_clean = evaluate_model(
    global_model_clean, device, test_loader, test_poison_loader, n_classes=10, backdoor_target=0)

clean_acc_poison, class_acc_poison, asr_poison = evaluate_model(
    global_model_poison, device, test_loader, test_poison_loader, n_classes=10, backdoor_target=0)

print("=== 全局干净模型评估结果 ===")
print(f"Clean Test Accuracy: {clean_acc_clean:.2f}%")
print(f"Backdoor Attack Success Rate (ASR): {asr_clean:.2f}%")
print("各类别准确率:")
for i, acc in enumerate(class_acc_clean):
    print(f"  Class {i}: {acc:.2f}%")

print("\n=== 全局投毒模型评估结果 ===")
print(f"Clean Test Accuracy: {clean_acc_poison:.2f}%")
print(f"Backdoor Attack Success Rate (ASR): {asr_poison:.2f}%")
print("各类别准确率:")
for i, acc in enumerate(class_acc_poison):
    print(f"  Class {i}: {acc:.2f}%")
# Out:
# === 全局干净模型评估结果 ===
# Clean Test Accuracy: 77.11%
# Backdoor Attack Success Rate (ASR): 12.45%
# 各类别准确率:
#   Class 0: 98.57%
#   Class 1: 98.50%
#   Class 2: 57.56%
#   Class 3: 84.36%
#   Class 4: 78.72%
#   Class 5: 45.85%
#   Class 6: 92.07%
#   Class 7: 90.08%
#   Class 8: 64.17%
#   Class 9: 56.10%
#
# === 全局投毒模型评估结果 ===
# Clean Test Accuracy: 79.26%
# Backdoor Attack Success Rate (ASR): 59.70%
# 各类别准确率:
#   Class 0: 89.49%
#   Class 1: 96.21%
#   Class 2: 57.75%
#   Class 3: 83.86%
#   Class 4: 87.58%
#   Class 5: 67.71%
#   Class 6: 84.97%
#   Class 7: 86.67%
#   Class 8: 76.08%
#   Class 9: 59.86%
