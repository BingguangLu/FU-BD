# %% [markdown]
# # 联邦学习简单实现 —— FedAvg 算法
#
# 本 Notebook 实现了一个简单的联邦学习示例。我们将使用 MNIST 数据集，将训练数据分成多个客户端，每个客户端在本地训练一个简单的神经网络（MLP），然后采用 FedAvg 算法对各客户端的模型参数进行平均聚合，更新全局模型。整个过程分为数据加载与划分、模型定义、局部训练、模型聚合和全局评估等步骤。

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# 超参数设置
num_clients = 5        # 客户端数量
local_epochs = 1       # 每个客户端本地训练的轮数
batch_size = 32        # 批次大小
num_rounds = 20         # 联邦学习的通信轮数
device = "cuda:0" if torch.cuda.is_available() else "cpu"
n_classes = 10
# Out:
# /home/bingguang/opt/anaconda3/envs/iv/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/bingguang/opt/anaconda3/envs/iv/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ## 数据加载与客户端数据划分
# 我们使用 MNIST 数据集，并将训练数据均匀划分给多个客户端。每个客户端拥有自己独立的数据子集。

# %%
# 数据预处理：将图片转换为 tensor 并归一化
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.1307,), (0.3081,))
])

# 下载 MNIST 数据集
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset  = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# 将训练集均分给各个客户端（这里简单采用均分的方式）
#client_data_sizes = [len(train_dataset) // num_clients] * num_clients
#client_datasets = random_split(train_dataset, client_data_sizes)
#client_loaders = [DataLoader(dataset, batch_size=batch_size, shuffle=True) for dataset in client_datasets]

# %% [markdown]
# ## 使用 Shard-based 方法进行非 IID 数据划分
#
# 该方法的基本步骤如下：
# 1. 按照标签对整个数据集进行排序。
# 2. 将排序后的数据集均分为若干个 shard，每个 shard 内的数据具有相似标签分布。
# 3. 随机将这些 shard 分配给各个客户端，每个客户端获得固定数量的 shard，从而形成非 IID 数据分布。
# 4. 固定随机种子保证每次运行结果一致。

# %%
import numpy as np
import random
import torch
from torch.utils.data import Subset
import matplotlib.pyplot as plt

def shard_based_partition(dataset, n_clients, n_shards_per_client, seed=42):
    """
    使用 shard-based 方法将数据集划分给 n_clients 个客户端。
    
    参数:
        dataset: torch 数据集，要求 dataset.targets 为 tensor 类型的标签
        n_clients: 客户端数量
        n_shards_per_client: 每个客户端获得的 shard 数量
        seed: 随机种子，保证结果可复现
        
    返回:
        client_subsets: 长度为 n_clients 的 Subset 列表，每个 Subset 表示分配给对应客户端的数据
    """
    # 固定随机种子
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    
    # 总 shard 数量 = 客户端数量 * 每个客户端的 shard 数量
    n_shards = n_clients * n_shards_per_client
    dataset_size = len(dataset)
    shard_size = dataset_size // n_shards
    
    # 按标签对数据集进行排序
    targets = dataset.targets.numpy()
    indices = np.argsort(targets)
    
    # 将排序后的 indices 分割成 n_shards 个 shard，每个 shard 包含连续的 shard_size 个样本
    shards = [indices[i * shard_size: (i + 1) * shard_size] for i in range(n_shards)]
    
    # 随机打乱 shard 的顺序
    shard_ids = np.arange(n_shards)
    np.random.shuffle(shard_ids)
    
    # 分配 shards 给各个客户端
    client_indices = {i: [] for i in range(n_clients)}
    for i in range(n_clients):
        assigned_shard_ids = shard_ids[i * n_shards_per_client: (i + 1) * n_shards_per_client]
        for shard_id in assigned_shard_ids:
            client_indices[i].extend(shards[shard_id].tolist())
    
    # 生成每个客户端的 Subset
    client_subsets = [Subset(dataset, client_indices[i]) for i in range(n_clients)]
    return client_subsets

# 示例使用：假设 train_dataset 已经定义为 MNIST 训练集
n_clients = 5
n_shards_per_client = 2  # 例如，每个客户端获得 2 个 shard
client_datasets = shard_based_partition(train_dataset, n_clients, n_shards_per_client, seed=42)

client_loaders = [DataLoader(dataset, batch_size=batch_size, shuffle=True) for dataset in client_datasets]

# %% [markdown]
# ## 可视化各客户端的标签分布
#
# 下面统计每个客户端中各类别（0～9）的样本数量，并绘制堆叠柱状图展示分布情况。

# %%
n_classes = 10  # MNIST 有 10 个类别
client_class_counts = []

for client_subset in client_datasets:
    indices = client_subset.indices
    labels = train_dataset.targets[indices].numpy()
    counts = [np.sum(labels == i) for i in range(n_classes)]
    client_class_counts.append(counts)
client_class_counts = np.array(client_class_counts)  # 形状: (n_clients, n_classes)

plt.figure(figsize=(12, 8))
client_ids = np.arange(n_clients)
bottom = np.zeros(n_clients)
colors = plt.cm.tab10.colors  # 10种颜色

for cls in range(n_classes):
    plt.bar(client_ids, client_class_counts[:, cls], bottom=bottom, 
            color=colors[cls], label=f"Class {cls}")
    bottom += client_class_counts[:, cls]

plt.xlabel("Client ID")
plt.ylabel("Number of Samples")
plt.title("Label Distribution per Client (Shard-based Partitioning)")
plt.xticks(client_ids, [f"Client {i}" for i in client_ids])
plt.legend(title="Class")
plt.show()

# %% [markdown]
# ## 定义模型
# 这里我们定义一个简单的全连接神经网络（MLP），用于 MNIST 手写数字分类。模型由一个隐藏层构成。

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 10)
    
    def forward(self, x):
        # 将 28x28 的图像展平为 784 维向量
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ## 局部训练函数
# 定义每个客户端的本地训练过程。每个客户端在自己的数据上训练若干个 epoch，并返回训练后的模型参数。

# %%
def local_train(model, dataloader, epochs, device):
    model.train()
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    criterion = nn.CrossEntropyLoss()
    for epoch in range(epochs):
        for data, target in dataloader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
    # 返回训练后的模型参数
    return model.state_dict()

# %% [markdown]
# ## FedAvg 聚合函数（数据量加权）
#
# 在实际应用中，各客户端的数据量可能不一致，因此在聚合时需要根据每个客户端的数据量进行加权：
# $$
# \theta_{global} = \sum_i \frac{n_i}{N_{total}} \theta_i
# $$
# 其中$ n_i $是客户端$ i $的数据量，$ N_{total} $是所有客户端数据量之和。

# %%
def fed_avg(global_model, client_state_dicts, client_data_counts):
    global_state_dict = global_model.state_dict()
    # 初始化全局模型参数为零
    for key in global_state_dict.keys():
        global_state_dict[key] = torch.zeros_like(global_state_dict[key])
    total_samples = sum(client_data_counts)
    # 对每个客户端的参数按数据量权重累加
    for client_state, n_samples in zip(client_state_dicts, client_data_counts):
        weight = n_samples / total_samples
        for key in global_state_dict.keys():
            global_state_dict[key] += client_state[key] * weight
    # 更新全局模型
    global_model.load_state_dict(global_state_dict)
    return global_model

# %% [markdown]
# ## 联邦学习主流程及每轮局部模型测试
# 在每一轮全局通信中，我们让每个客户端先在自己的本地训练后：
# - 使用其本地模型在整个测试集上进行评估（计算总体准确率和各类别准确率）。
# - 最后，将所有客户端的模型按照各自数据量的权重使用 FedAvg 进行聚合，形成更新后的全局模型。
#
# 这样可以帮助我们观察每个客户端在局部训练后的性能，同时也能追踪全局模型在聚合后的表现。

# %%
def evaluate_model(model, device, test_loader, n_classes=10):
    """
    在测试集上评估给定模型的表现，返回总体准确率及各类别准确率。
    """
    model.eval()
    correct = 0
    total = 0
    class_correct = [0 for _ in range(n_classes)]
    class_total = [0 for _ in range(n_classes)]
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            _, predicted = torch.max(output, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            for i in range(target.size(0)):
                label = target[i].item()
                class_total[label] += 1
                if predicted[i].item() == label:
                    class_correct[label] += 1
                    
    overall_accuracy = 100.0 * correct / total
    class_accuracies = [100.0 * c / t if t > 0 else 0.0 for c, t in zip(class_correct, class_total)]
    return overall_accuracy, class_accuracies

# 定义测试数据加载器
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# ## 联邦学习主流程（使用数据量加权的 FedAvg）
# 这里首先计算每个客户端的数据量，然后在每一轮通信中：
#
# - 将全局模型下发到各客户端进行本地训练；
# - 收集各客户端更新后的模型参数；
# - 使用上述加权 FedAvg 方法聚合各客户端模型参数，更新全局模型。

# %%
# 计算每个客户端数据量
client_data_counts = [len(dataset) for dataset in client_datasets]
print("每个客户端数据量:", client_data_counts)

global_model = SimpleNN().to(device)


for r in range(num_rounds):
    print(f"==== 第 {r+1} 轮通信 ====")
    client_state_dicts = []
    local_models = []
    
    # 遍历每个客户端，进行本地训练和测试
    for c_id, client_loader in enumerate(client_loaders):
        local_model = SimpleNN().to(device)
        # 同步全局模型参数到客户端
        local_model.load_state_dict(global_model.state_dict())
        # 客户端本地训练
        local_state = local_train(local_model, client_loader, local_epochs, device)
        client_state_dicts.append(local_state)
        local_models.append(local_model)
        
        # 测试当前客户端本地模型在整个测试集上的表现
        overall_acc, class_acc = evaluate_model(local_model, device, test_loader, n_classes)
        print(f"Client {c_id} local model test accuracy: {overall_acc:.2f}%")
        for i in range(n_classes):
            print(f"  Class {i} accuracy: {class_acc[i]:.2f}%")
    
    # 使用数据量加权的 FedAvg 聚合各客户端模型
    global_model = fed_avg(global_model, client_state_dicts, client_data_counts)
    
    # 选择性：测试聚合后的全局模型
    global_acc, global_class_acc = evaluate_model(global_model, device, test_loader, n_classes)
    print(f"Global model after round {r+1} test accuracy: {global_acc:.2f}%")
    for i in range(n_classes):
        print(f"  Global model Class {i} accuracy: {global_class_acc[i]:.2f}%")
    print("\n")
# Out:
# 每个客户端数据量: [12000, 12000, 12000, 12000, 12000]
# ==== 第 1 轮通信 ====
# Client 0 local model test accuracy: 26.99%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 97.80%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 60.31%
#   Class 8 accuracy: 99.49%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 27.19%
#   Class 0 accuracy: 98.78%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 88.80%
#   Class 5 accuracy: 98.54%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 30.77%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 94.45%
#   Class 2 accuracy: 97.97%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.69%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 27.90%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 87.62%
#   Class 4 accuracy: 96.95%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 94.45%
# Client 4 local model test accuracy: 26.82%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 71.22%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 1 test accuracy: 51.59%
#   Global model Class 0 accuracy: 15.51%
#   Global model Class 1 accuracy: 98.50%
#   Global model Class 2 accuracy: 78.97%
#   Global model Class 3 accuracy: 87.82%
#   Global model Class 4 accuracy: 84.83%
#   Global model Class 5 accuracy: 1.01%
#   Global model Class 6 accuracy: 0.31%
#   Global model Class 7 accuracy: 90.76%
#   Global model Class 8 accuracy: 41.99%
#   Global model Class 9 accuracy: 0.00%
#
#
# ==== 第 2 轮通信 ====
# Client 0 local model test accuracy: 28.44%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 98.41%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 74.22%
#   Class 8 accuracy: 98.97%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 32.64%
#   Class 0 accuracy: 99.08%
#   Class 1 accuracy: 44.93%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 92.46%
#   Class 5 accuracy: 98.09%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 30.82%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 94.45%
#   Class 2 accuracy: 98.64%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.50%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 28.03%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 88.81%
#   Class 4 accuracy: 97.56%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.10%
#   Class 9 accuracy: 93.86%
# Client 4 local model test accuracy: 29.19%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 75.68%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 18.48%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 2 test accuracy: 55.97%
#   Global model Class 0 accuracy: 43.27%
#   Global model Class 1 accuracy: 99.56%
#   Global model Class 2 accuracy: 81.98%
#   Global model Class 3 accuracy: 88.51%
#   Global model Class 4 accuracy: 92.67%
#   Global model Class 5 accuracy: 1.46%
#   Global model Class 6 accuracy: 1.15%
#   Global model Class 7 accuracy: 91.93%
#   Global model Class 8 accuracy: 43.53%
#   Global model Class 9 accuracy: 0.00%
#
#
# ==== 第 3 轮通信 ====
# Client 0 local model test accuracy: 28.89%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 98.24%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 78.60%
#   Class 8 accuracy: 99.18%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 32.75%
#   Class 0 accuracy: 98.78%
#   Class 1 accuracy: 47.14%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 90.73%
#   Class 5 accuracy: 98.77%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 31.10%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 96.92%
#   Class 2 accuracy: 98.55%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.60%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 28.27%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 1.23%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 89.11%
#   Class 4 accuracy: 94.91%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 0.41%
#   Class 9 accuracy: 96.73%
# Client 4 local model test accuracy: 31.89%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 0.00%
#   Class 2 accuracy: 76.26%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 44.26%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 3 test accuracy: 62.22%
#   Global model Class 0 accuracy: 71.53%
#   Global model Class 1 accuracy: 99.47%
#   Global model Class 2 accuracy: 83.24%
#   Global model Class 3 accuracy: 89.01%
#   Global model Class 4 accuracy: 94.09%
#   Global model Class 5 accuracy: 11.77%
#   Global model Class 6 accuracy: 11.48%
#   Global model Class 7 accuracy: 92.51%
#   Global model Class 8 accuracy: 55.85%
#   Global model Class 9 accuracy: 0.00%
#
#
# ==== 第 4 轮通信 ====
# Client 0 local model test accuracy: 28.96%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 98.41%
#   Class 2 accuracy: 0.00%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 79.09%
#   Class 8 accuracy: 99.18%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 37.48%
#   Class 0 accuracy: 98.98%
#   Class 1 accuracy: 77.80%
#   Class 2 accuracy: 0.39%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 92.36%
#   Class 5 accuracy: 98.65%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 10.12%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 31.17%
#   Class 0 accuracy: 0.00%
#   Class 1 accuracy: 97.18%
#   Class 2 accuracy: 98.64%
#   Class 3 accuracy: 0.20%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.69%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 30.77%
#   Class 0 accuracy: 2.65%
#   Class 1 accuracy: 17.09%
#   Class 2 accuracy: 1.36%
#   Class 3 accuracy: 89.01%
#   Class 4 accuracy: 94.91%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 3.39%
#   Class 9 accuracy: 97.03%
# Client 4 local model test accuracy: 33.35%
#   Class 0 accuracy: 0.10%
#   Class 1 accuracy: 0.70%
#   Class 2 accuracy: 78.39%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.48%
#   Class 7 accuracy: 55.25%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 4 test accuracy: 67.15%
#   Global model Class 0 accuracy: 85.00%
#   Global model Class 1 accuracy: 99.47%
#   Global model Class 2 accuracy: 84.59%
#   Global model Class 3 accuracy: 89.80%
#   Global model Class 4 accuracy: 95.21%
#   Global model Class 5 accuracy: 19.51%
#   Global model Class 6 accuracy: 30.06%
#   Global model Class 7 accuracy: 92.70%
#   Global model Class 8 accuracy: 63.76%
#   Global model Class 9 accuracy: 0.20%
#
#
# ==== 第 5 轮通信 ====
# Client 0 local model test accuracy: 29.67%
#   Class 0 accuracy: 0.41%
#   Class 1 accuracy: 98.24%
#   Class 2 accuracy: 0.10%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 1.22%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.10%
#   Class 7 accuracy: 84.44%
#   Class 8 accuracy: 99.18%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 39.99%
#   Class 0 accuracy: 98.88%
#   Class 1 accuracy: 83.26%
#   Class 2 accuracy: 1.36%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 93.08%
#   Class 5 accuracy: 98.88%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 26.75%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 31.28%
#   Class 0 accuracy: 0.31%
#   Class 1 accuracy: 97.27%
#   Class 2 accuracy: 98.74%
#   Class 3 accuracy: 0.59%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.89%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 36.04%
#   Class 0 accuracy: 13.78%
#   Class 1 accuracy: 40.00%
#   Class 2 accuracy: 5.91%
#   Class 3 accuracy: 87.13%
#   Class 4 accuracy: 96.23%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 15.61%
#   Class 9 accuracy: 96.83%
# Client 4 local model test accuracy: 33.31%
#   Class 0 accuracy: 0.20%
#   Class 1 accuracy: 2.73%
#   Class 2 accuracy: 76.45%
#   Class 3 accuracy: 98.81%
#   Class 4 accuracy: 0.00%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 54.47%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 5 test accuracy: 70.71%
#   Global model Class 0 accuracy: 90.41%
#   Global model Class 1 accuracy: 99.47%
#   Global model Class 2 accuracy: 85.85%
#   Global model Class 3 accuracy: 89.41%
#   Global model Class 4 accuracy: 95.32%
#   Global model Class 5 accuracy: 26.46%
#   Global model Class 6 accuracy: 46.87%
#   Global model Class 7 accuracy: 93.09%
#   Global model Class 8 accuracy: 68.99%
#   Global model Class 9 accuracy: 1.68%
#
#
# ==== 第 6 轮通信 ====
# Client 0 local model test accuracy: 30.05%
#   Class 0 accuracy: 1.63%
#   Class 1 accuracy: 98.24%
#   Class 2 accuracy: 0.39%
#   Class 3 accuracy: 0.10%
#   Class 4 accuracy: 3.26%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0

#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 7 test accuracy: 74.50%
#   Global model Class 0 accuracy: 93.88%
#   Global model Class 1 accuracy: 99.38%
#   Global model Class 2 accuracy: 86.82%
#   Global model Class 3 accuracy: 91.19%
#   Global model Class 4 accuracy: 95.21%
#   Global model Class 5 accuracy: 39.01%
#   Global model Class 6 accuracy: 62.94%
#   Global model Class 7 accuracy: 93.58%
#   Global model Class 8 accuracy: 71.87%
#   Global model Class 9 accuracy: 3.67%
#
#
# ==== 第 8 轮通信 ====
# Client 0 local model test accuracy: 32.53%
#   Class 0 accuracy: 8.57%
#   Class 1 accuracy: 98.77%
#   Class 2 accuracy: 2.42%
#   Class 3 accuracy: 0.40%
#   Class 4 accuracy: 13.34%
#   Class 5 accuracy: 0.11%
#   Class 6 accuracy: 3.97%
#   Class 7 accuracy: 85.99%
#   Class 8 accuracy: 99.08%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 42.21%
#   Class 0 accuracy: 98.88%
#   Class 1 accuracy: 81.59%
#   Class 2 accuracy: 6.20%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 90.84%
#   Class 5 accuracy: 98.99%
#   Class 6 accuracy: 0.10%
#   Class 7 accuracy: 47.28%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 32.06%
#   Class 0 accuracy: 2.24%
#   Class 1 accuracy: 97.80%
#   Class 2 accuracy: 98.55%
#   Class 3 accuracy: 5.54%
#   Class 4 accuracy: 0.31%
#   Class 5 accuracy: 0.00%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 97.08%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 44.43%
#   Class 0 accuracy: 36.53%
#   Class 1 accuracy: 65.99%
#   Class 2 accuracy: 18.70%
#   Class 3 accuracy: 86.93%
#   Class 4 accuracy: 95.72%
#   Class 5 accuracy: 0.22%
#   Class 6 accuracy: 0.10%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 34.50%
#   Class 9 accuracy: 97.72%
# Client 4 local model test accuracy: 38.16%
#   Class 0 accuracy: 12.96%
#   Class 1 accuracy: 15.24%
#   Class 2 accuracy: 81.49%
#   Class 3 accuracy: 99.01%
#   Class 4 accuracy: 0.10%
#   Class 5 accuracy: 1.68%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 68.87%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Global model after round 8 test accuracy: 76.70%
#   Global model Class 0 accuracy: 94.08%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 87.11%
#   Global model Class 3 accuracy: 89.70%
#   Global model Class 4 accuracy: 95.11%
#   Global model Class 5 accuracy: 48.43%
#   Global model Class 6 accuracy: 68.48%
#   Global model Class 7 accuracy: 93.87%
#   Global model Class 8 accuracy: 77.00%
#   Global model Class 9 accuracy: 7.83%
#
#
# ==== 第 9 轮通信 ====
# Client 0 local model test accuracy: 33.50%
#   Class 0 accuracy: 10.10%
#   Class 1 accuracy: 98.77%
#   Class 2 accuracy: 2.81%
#   Class 3 accuracy: 0.50%
#   Class 4 accuracy: 18.53%
#   Class 5 accuracy: 0.11%
#   Class 6 accuracy: 5.85%
#   Class 7 accuracy: 86.58%
#   Class 8 accuracy: 99.28%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 44.34%
#   Class 0 accuracy: 98.98%
#   Class 1 accuracy: 88.81%
#   Class 2 accuracy: 8.91%
#   Class 3 accuracy: 0.00%
#   Class 4 accuracy: 93.08%
#   Class 5 accuracy: 98.65%
#   Class 6 accuracy: 0.21%
#   Class 7 accuracy: 55.25%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 31.93%
#   Class 0 accuracy: 2.65%
#   Class 1 accuracy: 97.44%
#   Class 2 accuracy: 98.64%
#   Class 3 accuracy: 3.66%
#   Class 4 accuracy: 0.51%
#   Class 5 accuracy: 0.34%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 97.08%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 44.96%
#   Class 0 accuracy: 43.57%
#   Class 1 accuracy: 60.09%
#   Class 2 accuracy: 18.02%
#   Class 3 accuracy: 93.56%
#   Class 4 accuracy: 96.95%
#   Class 5 accuracy: 0.56%
#   Class 6 accuracy: 0.52%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy:

#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 49.08%
#   Class 9 accuracy: 96.73%
# Client 4 local model test accuracy: 44.25%
#   Class 0 accuracy: 35.41%
#   Class 1 accuracy: 31.63%
#   Class 2 accuracy: 86.43%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 2.65%
#   Class 5 accuracy: 6.84%
#   Class 6 accuracy: 99.16%
#   Class 7 accuracy: 77.04%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.10%
# Global model after round 12 test accuracy: 80.40%
#   Global model Class 0 accuracy: 95.82%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 87.98%
#   Global model Class 3 accuracy: 90.59%
#   Global model Class 4 accuracy: 94.50%
#   Global model Class 5 accuracy: 58.97%
#   Global model Class 6 accuracy: 79.02%
#   Global model Class 7 accuracy: 94.26%
#   Global model Class 8 accuracy: 81.72%
#   Global model Class 9 accuracy: 17.34%
#
#
# ==== 第 13 轮通信 ====
# Client 0 local model test accuracy: 35.76%
#   Class 0 accuracy: 17.04%
#   Class 1 accuracy: 99.03%
#   Class 2 accuracy: 4.26%
#   Class 3 accuracy: 0.89%
#   Class 4 accuracy: 26.88%
#   Class 5 accuracy: 0.11%
#   Class 6 accuracy: 10.75%
#   Class 7 accuracy: 87.35%
#   Class 8 accuracy: 99.18%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 45.43%
#   Class 0 accuracy: 99.49%
#   Class 1 accuracy: 89.52%
#   Class 2 accuracy: 13.18%
#   Class 3 accuracy: 0.30%
#   Class 4 accuracy: 90.84%
#   Class 5 accuracy: 98.21%
#   Class 6 accuracy: 1.04%
#   Class 7 accuracy: 61.77%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 2 local model test accuracy: 33.11%
#   Class 0 accuracy: 8.47%
#   Class 1 accuracy: 97.18%
#   Class 2 accuracy: 98.64%
#   Class 3 accuracy: 5.54%
#   Class 4 accuracy: 1.32%
#   Class 5 accuracy: 4.60%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.98%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 49.84%
#   Class 0 accuracy: 51.84%
#   Class 1 accuracy: 73.66%
#   Class 2 accuracy: 26.55%
#   Class 3 accuracy: 90.69%
#   Class 4 accuracy: 95.93%
#   Class 5 accuracy: 2.02%
#   Class 6 accuracy: 3.76%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 48.05%
#   Class 9 accuracy: 97.72%
# Client 4 local model test accuracy: 44.30%
#   Class 0 accuracy: 37.14%
#   Class 1 accuracy: 31.10%
#   Class 2 accuracy: 86.82%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 2.55%
#   Class 5 accuracy: 9.42%
#   Class 6 accuracy: 99.16%
#   Class 7 accuracy: 73.83%
#   Class 8 accuracy: 0.10%
#   Class 9 accuracy: 0.10%
# Global model after round 13 test accuracy: 81.75%
#   Global model Class 0 accuracy: 95.71%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 88.95%
#   Global model Class 3 accuracy: 89.70%
#   Global model Class 4 accuracy: 94.30%
#   Global model Class 5 accuracy: 62.78%
#   Global model Class 6 accuracy: 80.27%
#   Global model Class 7 accuracy: 94.36%
#   Global model Class 8 accuracy: 82.65%
#   Global model Class 9 accuracy: 25.37%
#
#

#   Class 8 accuracy: 0.10%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 51.66%
#   Class 0 accuracy: 57.45%
#   Class 1 accuracy: 73.04%
#   Class 2 accuracy: 28.88%
#   Class 3 accuracy: 93.37%
#   Class 4 accuracy: 96.33%
#   Class 5 accuracy: 2.69%
#   Class 6 accuracy: 5.22%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 55.13%
#   Class 9 accuracy: 96.73%
# Client 4 local model test accuracy: 44.26%
#   Class 0 accuracy: 39.69%
#   Class 1 accuracy: 31.72%
#   Class 2 accuracy: 84.79%
#   Class 3 accuracy: 99.11%
#   Class 4 accuracy: 3.87%
#   Class 5 accuracy: 8.41%
#   Class 6 accuracy: 99.16%
#   Class 7 accuracy: 71.60%
#   Class 8 accuracy: 0.10%
#   Class 9 accuracy: 0.10%
# Global model after round 15 test accuracy: 82.57%
#   Global model Class 0 accuracy: 95.82%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 89.34%
#   Global model Class 3 accuracy: 91.09%
#   Global model Class 4 accuracy: 94.50%
#   Global model Class 5 accuracy: 64.69%
#   Global model Class 6 accuracy: 81.73%
#   Global model Class 7 accuracy: 94.26%
#   Global model Class 8 accuracy: 82.96%
#   Global model Class 9 accuracy: 28.15%
#
#
# ==== 第 16 轮通信 ====
# Client 0 local model test accuracy: 36.64%
#   Class 0 accuracy: 19.08%
#   Class 1 accuracy: 99.38%
#   Class 2 accuracy: 5.43%
#   Class 3 accuracy: 1.39%
#   Class 4 accuracy: 30.04%
#   Class 5 accuracy: 0.22%
#   Class 6 accuracy: 13.15%
#   Class 7 accuracy: 86.48%
#   Class 8 accuracy: 99.28%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 47.61%
#   Class 0 accuracy: 99.08%
#   Class 1 accuracy: 92.07%
#   Class 2 accuracy: 19.19%
#   Class 3 accuracy: 0.79%
#   Class 4 accuracy: 94.50%
#   Class 5 accuracy: 98.88%
#   Class 6 accuracy: 2.92%
#   Class 7 accuracy: 68.09%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.10%
# Client 2 local model test accuracy: 34.00%
#   Class 0 accuracy: 10.41%
#   Class 1 accuracy: 97.62%
#   Class 2 accuracy: 98.64%
#   Class 3 accuracy: 6.24%
#   Class 4 accuracy: 2.04%
#   Class 5 accuracy: 9.87%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 97.08%
#   Class 8 accuracy: 0.31%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 51.64%
#   Class 0 accuracy: 58.16%
#   Class 1 accuracy: 72.42%
#   Class 2 accuracy: 32.56%
#   Class 3 accuracy: 91.58%
#   Class 4 accuracy: 96.95%
#   Class 5 accuracy: 3.03%
#   Class 6 accuracy: 5.53%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 51.13%
#   Class 9 accuracy: 97.22%
# Client 4 local model test accuracy: 44.57%
#   Class 0 accuracy: 37.76%
#   Class 1 accuracy: 34.89%
#   Class 2 accuracy: 85.17%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 2.55%
#   Class 5 accuracy: 7.06%
#   Class 6 accuracy: 99.37%
#   Class 7 accuracy: 75.10%
#   Class 8 accuracy: 0.31%
#   Class 9 accuracy: 0.10%
# Global model after round 16 test accuracy: 82.90%
#   Global model Class 0 accuracy: 95.82%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 89.53%
#   Global model Class 3 accuracy: 90.40%
#   Global model Class 4 accuracy: 95.11%
#   Global model Class 5 accuracy: 64.13%
#   Global model Class 6 accuracy: 82.78%
#   Global model Class 7 accuracy: 94.55%
#   Global model Class 8 accuracy: 83.98%
#   Global model Class 9 accuracy: 29.53%
#
#
# ==== 第 17 轮通信 ====
# Client 0 local model test accuracy: 37.93%
#   Class 0 accuracy: 21.12%
#   Class 1 accuracy: 99.03%
#   Class 2 accuracy: 6.49%
#   Class 3 accuracy: 1.68%
#   Class 4 accuracy: 34.73%
#   Class 5 accuracy: 0.22%
#   Class 6 accuracy: 15.24%
#   Class 7 accuracy: 89.59%
#   Class 8 accuracy: 99.38%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 47.71%
#   Class 0 accuracy: 99.08%
#   Class 1 accuracy: 92.33%
#   Class 2 accuracy: 20.45%
#   Class 3 accuracy: 0.79%
#   Class 4 accuracy: 95.01%
#   Class 5 accuracy: 98.99%
#   Class 6 accuracy: 2.51%
#   Class 7 accuracy: 67.32%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.10%
# Client 2 local model test accuracy: 34.66%
#   Class 0 accuracy: 10.92%
#   Class 1 accuracy: 98.41%
#   Class 2 accuracy: 98.93%
#   Class 3 accuracy: 9.01%
#   Class 4 accuracy: 2.95%
#   Class 5 accuracy: 11.66%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.69%
#   Class 8 accuracy: 0.31%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 52.00%
#   Class 0 accuracy: 55.31%
#   Class 1 accuracy: 75.68%
#   Class 2 accuracy: 30.14%
#   Class 3 accuracy: 91.19%
#   Class 4 accuracy: 96.44%
#   Class 5 accuracy: 2.80%
#   Class 6 accuracy: 7.72%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 54.93%
#   Class 9 accuracy: 97.72%
# Client 4 local model test accuracy: 46.09%
#   Class 0 accuracy: 41.63%
#   Class 1 accuracy: 33.13%
#   Class 2 accuracy: 88.76%
#   Class 3 accuracy: 98.71%
#   Class 4 accuracy: 7.03%
#   Class 5 accuracy: 10.43%
#   Class 6 accuracy: 99.16%
#   Class 7 accuracy: 77.24%
#   Class 8 accuracy: 0.51%
#   Class 9 accuracy: 0.10%
# Global model after round 17 test accuracy: 83.33%
#   Global model Class 0 accuracy: 95.31%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 89.63%
#   Global model Class 3 accuracy: 90.10%
#   Global model Class 4 accuracy: 95.11%
#   Global model Class 5 accuracy: 66.70%
#   Global model Class 6 accuracy: 82.46%
#   Global model Class 7 accuracy: 94.55%
#   Global model Class 8 accuracy: 83.98%
#   Global model Class 9 accuracy: 32.51%
#
#
# ==== 第 18 轮通信 ====
# Client 0 local model test accuracy: 37.98%
#   Class 0 accuracy: 23.67%
#   Class 1 accuracy: 98.85%
#   Class 2 accuracy: 6.59%
#   Class 3 accuracy: 1.49%
#   Class 4 accuracy: 31.87%
#   Class 5 accuracy: 0.22%
#   Class 6 accuracy: 15.14%
#   Class 7 accuracy: 90.76%
#   Class 8 accuracy: 99.38%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 48.11%
#   Class 0 accuracy: 99.29%
#   Class 1 accuracy: 92.60%
#   Class 2 accuracy: 19.96%
#   Class 3 accuracy: 1.19%
#   Class 4 accuracy: 95.21%
#   Class 5 accuracy: 98.65%
#   Class 6 accuracy: 4.38%
#   Class 7 accuracy: 69.07%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.20%
# Client 2 local model test accuracy: 34.73%
#   Class 0 accuracy: 11.63%
#   Class 1 accuracy: 98.50%
#   Class 2 accuracy: 98.84%
#   Class 3 accuracy: 8.32%
#   Class 4 accuracy: 2.75%
#   Class 5 accuracy: 12.56%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.69%
#   Class 8 accuracy: 0.41%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 52.60%
#   Class 0 accuracy: 56.73%
#   Class 1 accuracy: 77.27%
#   Class 2 accuracy: 31.88%
#   Class 3 accuracy: 92.57%
#   Class 4 accuracy: 97.35%
#   Class 5 accuracy: 3.36%
#   Class 6 accuracy: 5.85%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 55.75%
#   Class 9 accuracy: 96.93%
# Client 4 local model test accuracy: 47.07%
#   Class 0 accuracy: 44.90%
#   Class 1 accuracy: 33.83%
#   Class 2 accuracy: 90.99%
#   Class 3 accuracy: 98.61%
#   Class 4 accuracy: 9.47%
#   Class 5 accuracy: 11.55%
#   Class 6 accuracy: 99.06%
#   Class 7 accuracy: 77.33%
#   Class 8 accuracy: 0.72%
#   Class 9 accuracy: 0.10%
# Global model after round 18 test accuracy: 83.44%
#   Global model Class 0 accuracy: 96.02%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 89.63%
#   Global model Class 3 accuracy: 90.50%
#   Global model Class 4 accuracy: 94.91%
#   Global model Class 5 accuracy: 67.71%
#   Global model Class 6 accuracy: 82.46%
#   Global model Class 7 accuracy: 94.55%
#   Global model Class 8 accuracy: 84.50%
#   Global model Class 9 accuracy: 31.32%
#
#
# ==== 第 19 轮通信 ====
# Client 0 local model test accuracy: 38.43%
#   Class 0 accuracy: 24.90%
#   Class 1 accuracy: 99.38%
#   Class 2 accuracy: 6.98%
#   Class 3 accuracy: 1.39%
#   Class 4 accuracy: 37.27%
#   Class 5 accuracy: 0.34%
#   Class 6 accuracy: 15.34%
#   Class 7 accuracy: 87.74%
#   Class 8 accuracy: 99.28%
#   Class 9 accuracy: 0.00%
# Client 1 local model test accuracy: 49.01%
#   Class 0 accuracy: 99.29%
#   Class 1 accuracy: 94.10%
#   Class 2 accuracy: 23.26%
#   Class 3 accuracy: 1.68%
#   Class 4 accuracy: 95.72%
#   Class 5 accuracy: 98.99%
#   Class 6 accuracy: 4.70%
#   Class 7 accuracy: 71.30%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.20%
# Client 2 local model test accuracy: 35.02%
#   Class 0 accuracy: 13.47%
#   Class 1 accuracy: 98.50%
#   Class 2 accuracy: 99.13%
#   Class 3 accuracy: 8.61%
#   Class 4 accuracy: 3.16%
#   Class 5 accuracy: 12.89%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 96.50%
#   Class 8 accuracy: 0.41%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 52.69%
#   Class 0 accuracy: 60.20%
#   Class 1 accuracy: 74.45%
#   Class 2 accuracy: 31.40%
#   Class 3 accuracy: 92.97%
#   Class 4 accuracy: 98.27%
#   Class 5 accuracy: 4.04%
#   Class 6 accuracy: 5.95%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 56.47%
#   Class 9 accuracy: 95.44%
# Client 4 local model test accuracy: 45.00%
#   Class 0 accuracy: 45.10%
#   Class 1 accuracy: 28.37%
#   Class 2 accuracy: 84.21%
#   Class 3 accuracy: 99.50%
#   Class 4 accuracy: 8.04%
#   Class 5 accuracy: 9.42%
#   Class 6 accuracy: 99.06%
#   Class 7 accuracy: 72.67%
#   Class 8 accuracy: 0.21%
#   Class 9 accuracy: 0.10%
# Global model after round 19 test accuracy: 83.88%
#   Global model Class 0 accuracy: 96.33%
#   Global model Class 1 accuracy: 99.30%
#   Global model Class 2 accuracy: 89.24%
#   Global model Class 3 accuracy: 91.29%
#   Global model Class 4 accuracy: 95.42%
#   Global model Class 5 accuracy: 66.26%
#   Global model Class 6 accuracy: 82.05%
#   Global model Class 7 accuracy: 94.26%
#   Global model Class 8 accuracy: 84.60%
#   Global model Class 9 accuracy: 36.37%
#
#
# ==== 第 20 轮通信 ====
# Client 0 local model test accuracy: 38.07%
#   Class 0 accuracy: 22.14%
#   Class 1 accuracy: 99.30%
#   Class 2 accuracy: 6.01%
#   Class 3 accuracy: 1.49%
#   Class 4 accuracy: 34.83%
#   Class 5 accuracy: 0.34%
#   Class 6 accuracy: 15.03%
#   Class 7 accuracy: 90.27%
#   Class 8 accuracy: 99.38%
#   Class 9 accuracy: 0.10%
# Client 1 local model test accuracy: 47.89%
#   Class 0 accuracy: 99.18%
#   Class 1 accuracy: 91.89%
#   Class 2 accuracy: 21.41%
#   Class 3 accuracy: 0.99%
#   Class 4 accuracy: 90.94%
#   Class 5 accuracy: 99.33%
#   Class 6 accuracy: 5.32%
#   Class 7 accuracy: 68.58%
#   Class 8 accuracy: 0.00%
#   Class 9 accuracy: 0.79%
# Client 2 local model test accuracy: 34.96%
#   Class 0 accuracy: 15.10%
#   Class 1 accuracy: 97.62%
#   Class 2 accuracy: 98.84%
#   Class 3 accuracy: 7.82%
#   Class 4 accuracy: 2.04%
#   Class 5 accuracy: 13.23%
#   Class 6 accuracy: 0.00%
#   Class 7 accuracy: 97.18%
#   Class 8 accuracy: 0.41%
#   Class 9 accuracy: 0.00%
# Client 3 local model test accuracy: 53.73%
#   Class 0 accuracy: 59.29%
#   Class 1 accuracy: 74.98%
#   Class 2 accuracy: 31.69%
#   Class 3 accuracy: 92.08%
#   Class 4 accuracy: 95.93%
#   Class 5 accuracy: 4.15%
#   Class 6 accuracy: 9.71%
#   Class 7 accuracy: 0.00%
#   Class 8 accuracy: 64.17%
#   Class 9 accuracy: 97.82%
# Client 4 local model test accuracy: 46.28%
#   Class 0 accuracy: 47.86%
#   Class 1 accuracy: 31.28%
#   Class 2 accuracy: 83.14%
#   Class 3 accuracy: 99.50%
#   Class 4 accuracy: 11.61%
#   Class 5 accuracy: 9.87%
#   Class 6 accuracy: 99.27%
#   Class 7 accuracy: 76.36%
#   Class 8 accuracy: 0.21%
#   Class 9 accuracy: 0.10%
# Global model after round 20 test accuracy: 83.86%
#   Global model Class 0 accuracy: 96.43%
#   Global model Class 1 accuracy: 99.21%
#   Global model Class 2 accuracy: 89.44%
#   Global model Class 3 accuracy: 91.39%
#   Global model Class 4 accuracy: 94.09%
#   Global model Class 5 accuracy: 67.94%
#   Global model Class 6 accuracy: 84.34%
#   Global model Class 7 accuracy: 95.14%
#   Global model Class 8 accuracy: 85.52%
#   Global model Class 9 accuracy: 31.71%
